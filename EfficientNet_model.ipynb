# %% [markdown]
# ## SENG 533 — EfficientNet - B0
# ### Setup, Instrumentation and Controlled Experiment

# %%
# %pip install torchinfo imutils -q

import os
import random
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
from torchvision import models
from torchinfo import summary
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score

# %%
# Logging Setup
import logging

logger = logging.getLogger(__name__)

# Remove any existing handlers before adding new ones
if logger.hasHandlers():
    logger.handlers.clear()

logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)

# %% [markdown]
# ### 1 · Instrumentation & Reproducibility Helpers

# %%
import time
import csv

LOG_FILE = "performance_logs.csv"

# ── Reproducibility ───
def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def seed_worker(worker_id):
    """Ensures DataLoader workers are seeded for full reproducibility."""
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# ── GPU Device Setup ───
def get_gpu_type():
    """Returns the available GPU device or CPU if none are available."""
    if torch.cuda.is_available():
        device = torch.cuda.get_device_name(0)
        logger.info(f"GPU found: {torch.cuda.get_device_name(0)}. Using GPU.")

    else:
        device = torch.device("cpu")
        logger.info("No GPU found. Using CPU.")
    return device

def get_gpu_memory():
    """Returns (current_allocated_MB, peak_allocated_MB) for the current GPU."""
    if torch.cuda.is_available():
        current_allocated = torch.cuda.memory_allocated(0) / (1024 ** 2)  # Convert to MB
        peak_allocated = torch.cuda.max_memory_allocated(0) / (1024 ** 2)  # Convert to MB
        return round(current_allocated, 2), round(peak_allocated, 2)
    else:
        return 0, 0

def reset_gpu_memory():
    """Resets GPU memory tracking to get accurate measurements for the next operation."""
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats()

def cuda_sync():
    """Ensures all CUDA operations are completed before measuring time or memory."""
    if torch.cuda.is_available():
        torch.cuda.synchronize()

# Clear existing log file for a fresh start
if os.path.exists(LOG_FILE):
    os.remove(LOG_FILE)
    print(f"Cleared existing {LOG_FILE} for a fresh experiment run.")

# ── Performance Logging ───
def init_log():

    with open(LOG_FILE, mode='w', newline='') as file:
        csv.writer(file).writerow([
            'model', 'batch_size', 'num_epochs', 'gpu_type',
            'run_number', 'total_training_time_sec', 'avg_time_per_epoch_sec',
            'inference_latency_single_img_sec', 'inference_latency_batch_sec',
            'throughput_img_per_sec',
            'gpu_memory_allocated_MB', 'gpu_memory_peak_MB',
            'validation_accuracy_pct', 'f1_score'

        ])
    print(f"Performance log initialized at {LOG_FILE}\n Logging will be saved to this file.")

def log_performance(model_name, batch_size, num_epochs, gpu_type, run_num,
                    total_time, avg_epoch, lat_single, lat_batch, throughput,
                    mem_used, mem_peak, val_acc, f1):
    with open(LOG_FILE, mode='a', newline='') as file:
        csv.writer(file).writerow([
            model_name, batch_size, num_epochs, gpu_type,
            run_num, round(total_time, 2), round(avg_epoch, 2),
            round(lat_single, 4), round(lat_batch, 4), round(throughput, 2),
            mem_used, mem_peak,
            round(val_acc, 2), round(f1, 2)
        ])

    logger.info(f"Logged performance for {model_name} (Run {run_num}) to {LOG_FILE}")
    logger.info(f" Logged: bs={batch_size} | epochs={num_epochs} | gpu={gpu_type} ")

seed_everything(42)
init_log()
logger.info(f'GPU Type: {get_gpu_type()}')
# Out:
# 2026-03-21 13:56:40,194 - INFO - GPU found: Tesla T4. Using GPU.
# INFO:__main__:GPU found: Tesla T4. Using GPU.
# 2026-03-21 13:56:40,195 - INFO - GPU Type: Tesla T4
# INFO:__main__:GPU Type: Tesla T4
# Performance log initialized at performance_logs.csv
#  Logging will be saved to this file.

# %% [markdown]
# ### 2 · Shared Preprocessing Pipeline

# %%
import cv2
import imutils
from PIL import Image
import torchvision
from torchvision import transforms

## Normalization - Standard for both Models
NET_MEAN = [0.485, 0.456, 0.406]
NET_STD = [0.229, 0.224, 0.225]
IMG_SIZE = 224 # Fixed Resolution for both models

def crop_img(img):
    """
    Crops out the brain region from an MRI scan using contour detection.
    Applied as the first preprocessing step for both models.
    This function assumes the brain is the largest contour in the image and crops to a square around it.
    Args:
        img (numpy array): Input MRI image as a NumPy array.
    """
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) # PIL images are in RGB format, not BGR
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)

    c = max(cnts, key=cv2.contourArea)
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])

    return img[extTop[1]:extBot[1], extLeft[0]:extRight[0]].copy()

class CropTransform:
    """Custom transform to crop the brain region from MRI scans."""
    def __call__(self, img):
        img_np = np.array(img)
        try:
            return Image.fromarray(crop_img(img_np))
        except Exception as e:
            logger.warning(f"Crop failed: {e}. Returning original image.")
            return img # If cropping fails, return the original image to avoid breaking the pipeline.

# Shared Transformations for both models
# Train: Crop -> Resize -> RandomHorizontalFlip -> ToTensor -> Normalize
# Val/Test: Crop -> Resize -> ToTensor -> Normalize : No data augmentation during validation/testing to ensure consistent evaluation.

TRAIN_TRANSFORMS = transforms.Compose([
    CropTransform(),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=NET_MEAN, std=NET_STD)
])

VAL_TEST_TRANSFORMS = transforms.Compose([
    CropTransform(),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=NET_MEAN, std=NET_STD)
])

logger.info("Shared Preprocessing and Augmentation Pipeline defined for both models.")
logger.info("Data transformations defined for training and validation/testing.")

logger.info(f"Resolution: {IMG_SIZE}x{IMG_SIZE} ")
logger.info(f"Normalization: mean={NET_MEAN}")
logger.info(f"Normalization: std={NET_STD}")
logger.info("Data augmentation: RandomHorizontalFlip applied only during training.")
logger.info("CropTransform applied to all datasets to focus on brain region.")
# Out:
# 2026-03-21 13:56:46,234 - INFO - Shared Preprocessing and Augmentation Pipeline defined for both models.
# INFO:__main__:Shared Preprocessing and Augmentation Pipeline defined for both models.
# 2026-03-21 13:56:46,236 - INFO - Data transformations defined for training and validation/testing.
# INFO:__main__:Data transformations defined for training and validation/testing.
# 2026-03-21 13:56:46,238 - INFO - Resolution: 224x224
# INFO:__main__:Resolution: 224x224
# 2026-03-21 13:56:46,240 - INFO - Normalization: mean=[0.485, 0.456, 0.406]
# INFO:__main__:Normalization: mean=[0.485, 0.456, 0.406]
# 2026-03-21 13:56:46,241 - INFO - Normalization: std=[0.229, 0.224, 0.225]
# INFO:__main__:Normalization: std=[0.229, 0.224, 0.225]
# 2026-03-21 13:56:46,243 - INFO - Data augmentation: RandomHorizontalFlip applied only during training.
# INFO:__main__:Data augmentation: RandomHorizontalFlip applied only during training.
# 2026-03-21 13:56:46,245 - INFO - CropTransform applied to all datasets to focus on brain region.
# INFO:__main__:CropTransform applied to all datasets to focus on brain region.

# %% [markdown]
# ### 3 · Dataset & DataLoader Builder

# %%
from torch.utils.data import DataLoader, WeightedRandomSampler, random_split

# ── Download dataset ──────
DATASET_DIR = kagglehub.dataset_download('masoudnickparvar/brain-tumor-mri-dataset')
CLASSES = ['glioma', 'meningioma', 'notumor', 'pituitary']
logger.info(f"Dataset downloaded from Kaggle: {DATASET_DIR}")
logger.info(f"Classes: {CLASSES}")

# ── Build base datasets ────
# Load the full Training folder (no transforms yet — just to get targets/indices)
_full_train_dataset = torchvision.datasets.ImageFolder(
    root=os.path.join(DATASET_DIR, 'Training'),
    transform=None
)

# ── Analyze class distribution ────
# 80/20 split of the full training dataset to create a validation set while maintaining class distribution.
_train_size = int(0.8 * len(_full_train_dataset))
_val_size = len(_full_train_dataset) - _train_size
_generator = torch.Generator().manual_seed(42)  # For reproducibility
_train_idx, _val_idx = random_split(
    range(len(_full_train_dataset)), [_train_size, _val_size], generator=_generator
)
logger.info(f"Full training dataset size: {len(_full_train_dataset)}")
logger.info(f"Training set size: {_train_size}")
logger.info(f"Validation set size: {_val_size}")

TRAIN_INDICES = list(_train_idx)
VAL_INDICES = list(_val_idx)

# Weighted  sampler targets - derived from splits to ensure the same class distribution in the weighted sampler as in the training set.
_train_targets = [_full_train_dataset.targets[i] for i in TRAIN_INDICES]
_class_counts = torch.bincount(torch.tensor(_train_targets))
_class_weights = 1.0 / _class_counts.float()
SAMPLE_WEIGHTS = [_class_weights[target] for target in _train_targets]

logger.info(f"Class counts: {_class_counts.tolist()}")
logger.info(f"Class weights: {_class_weights.tolist()}")


def make_loaders(batch_size):
    """
    Build fresh train/val/test DataLoaders for a given batch size.
    Uses shared TRAIN/VAL_TRANSFORMS, TRAIN/VAL_INDICES, and SAMPLE_WEIGHTS.
    Seeded workers ensure reproducibility across runs.
    """
    g = torch.Generator()
    g.manual_seed(42)

    # Train dataset with transforms
    _train_dataset = torch.utils.data.Subset(
        torchvision.datasets.ImageFolder(
            root=os.path.join(DATASET_DIR, 'Training'), transform=TRAIN_TRANSFORMS),
            TRAIN_INDICES
    )

    # Validation dataset with transforms
    _val_dataset = torch.utils.data.Subset(
        torchvision.datasets.ImageFolder(
            root=os.path.join(DATASET_DIR, 'Training'), transform=VAL_TEST_TRANSFORMS),
            VAL_INDICES
    )

    # Test dataset with transforms
    _test_dataset = torchvision.datasets.ImageFolder(
        root=os.path.join(DATASET_DIR, 'Testing'), transform=VAL_TEST_TRANSFORMS
    )

    # Weighted sampler for training set
    _train_sampler = WeightedRandomSampler(
        weights=SAMPLE_WEIGHTS,
        num_samples=len(SAMPLE_WEIGHTS),
        replacement=True,
    )

    # DataLoaders
    train_loader = DataLoader(
        _train_dataset, batch_size=batch_size, sampler=_train_sampler,
        num_workers=2, pin_memory=True,
        worker_init_fn=seed_worker, generator=g
    )

    val_loader = DataLoader(
        _val_dataset, batch_size=batch_size, shuffle=False,
        num_workers=2, pin_memory=True,
        worker_init_fn=seed_worker, generator=g
    )

    test_loader = DataLoader(
        _test_dataset, batch_size=batch_size, shuffle=False,
        num_workers=2, pin_memory=True,
        worker_init_fn=seed_worker, generator=g
    )

    return train_loader, val_loader, test_loader

logger.info("DataLoaders will be created on demand for each model and batch size using the make_loaders function.")
# Out:
# Using Colab cache for faster access to the 'brain-tumor-mri-dataset' dataset.
# 2026-03-21 13:56:50,635 - INFO - Dataset downloaded from Kaggle: /kaggle/input/brain-tumor-mri-dataset
# INFO:__main__:Dataset downloaded from Kaggle: /kaggle/input/brain-tumor-mri-dataset
# 2026-03-21 13:56:50,636 - INFO - Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# INFO:__main__:Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# 2026-03-21 13:56:54,287 - INFO - Full training dataset size: 5600
# INFO:__main__:Full training dataset size: 5600
# 2026-03-21 13:56:54,289 - INFO - Training set size: 4480
# INFO:__main__:Training set size: 4480
# 2026-03-21 13:56:54,290 - INFO - Validation set size: 1120
# INFO:__main__:Validation set size: 1120
# 2026-03-21 13:56:54,380 - INFO - Class counts: [1115, 1123, 1111, 1131]
# INFO:__main__:Class counts: [1115, 1123, 1111, 1131]
# 2026-03-21 13:56:54,381 - INFO - Class weights: [0.0008968609618023038, 0.0008904719725251198, 0.0009000900317914784, 0.0008841733215376735]
# INFO:__main__:Class weights: [0.0008968609618023038, 0.0008904719725251198, 0.0009000900317914784, 0.0008841733215376735]
# 2026-03-21 13:56:54,384 - INFO - DataLoaders will be created on demand for each model and batch size using the make_loaders function.
# INFO:__main__:DataLoaders will be created on demand for each model and batch size using the make_loaders function.

# %% [markdown]
# ### 4 · Model Architecture

# %%
# EfficientNet-B0 Model Definition

class EfficientNetB0Classifier(nn.Module):
    def __init__(self, num_classes=4):
        super().__init__()
        self.base_model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
        # Freeze all feauture layers
        for p in self.base_model.features.parameters():
            p.requires_grad = False
        # Unfreeze last features block for fine-tuning
        for p in self.base_model.features[8].parameters():
            p.requires_grad = True
        in_features = self.base_model.classifier[1].in_features
        self.base_model.classifier = nn.Sequential(
            nn.Dropout(p=0.4),
            nn.Linear(in_features, num_classes)
        )

    def forward(self, x):
        return self.base_model(x)

# Quick sanity check
_device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
_m = EfficientNetB0Classifier(num_classes=4).to(_device)
_x = torch.randn (2, 3, 224, 224).to(_device)
assert _m(_x).shape == (2, 4), "Model outputshape mismatch!"
logger.info("EfficienTB0 model defined and output shape verified with a dummy input")

# Log trainable layer summary
summary(
    _m,
    input_size=(1, 3, 224, 224),
    col_names=['input_size', 'num_params', 'trainable'],
    col_width=20,
    row_settings=['var_names'],
)
# Out:
# 2026-03-21 13:56:56,038 - INFO - Custom CNN model defined and output shape verified with a dummy input.
# INFO:__main__:Custom CNN model defined and output shape verified with a dummy input.

# %% [markdown]
# ### 5 · Full Experiment Loop

# %%
# 18 configurations × 3 runs = 54 total runs.
# All metrics logged to performance_logs.csv.

import torch.optim as optim
from sklearn.metrics import f1_score as sk_f1_score

BATCH_SIZES = [16, 32, 64]
EPOCH_COUNTS = [5, 10, 20] # 3 different epoch counts to evaluate the impact of training duration on performance and resource usage.
NUM_RUNS = 3
MODEL_NAME = "EfficientNet-B0"
LR = 0.001

device = torch.device('cuda') if torch.cuda.is_available() else torch.device("cpu")
gpu_type = get_gpu_type()

logger.info(f"Beginning training and evaluation for {MODEL_NAME} on Device: {device} - GPU: {gpu_type}")
logger.info(f"Starting training and evaluation for {MODEL_NAME} across configurations.")

best_val_acc = 0.0  # Track the best validation accuracy across all runs for summary logging at the end.
best_model_path = "best_efficientnet_b0.pth"  # Save best EfficientNet-B0 checkpoint based on validation accuracy.

for batch_size in BATCH_SIZES:
    for num_epochs in EPOCH_COUNTS:
        for run in range(1, NUM_RUNS + 1):
            logger.info(f"{MODEL_NAME} - Run {run}/{NUM_RUNS} | Batch Size: {batch_size} | Epochs: {num_epochs}")

            reset_gpu_memory()

            train_loader, val_loader, test_loader = make_loaders(batch_size)
            model = EfficientNetB0Classifier(num_classes=len(CLASSES)).to(device)
            criterion = torch.nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=LR)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode='min', factor=0.1, patience=3
            )

            # ── Training Loop ────
            epoch_times = []
            train_start_time = time.time()
            y_true_last, y_pred_last = [], []  # For final F1 score calculation on validation set
            last_epoch_val_loss = float('inf')

            for epoch in range(1, num_epochs + 1):
                model.train()
                epoch_start_time = time.time()

                for images, labels in train_loader:
                    images, labels = images.to(device), labels.to(device)
                    optimizer.zero_grad()
                    loss = criterion(model(images), labels)
                    loss.backward()
                    optimizer.step()

                cuda_sync() # Ensure all GPU operations are complete before timing
                epoch_times.append(time.time() - epoch_start_time)

                # ── Validation Loop ────
                model.eval()
                val_loss, val_correct, val_total = 0.0, 0, 0
                y_true, y_pred = [], []
                with torch.no_grad():
                    for images, labels in val_loader:
                        images, labels = images.to(device), labels.to(device)
                        outputs = model(images)
                        val_loss += criterion(outputs, labels).item()
                        _, predicted = torch.max(outputs.data, 1)
                        val_total += labels.size(0)
                        val_correct += (predicted == labels).sum().item()
                        y_true.extend(labels.cpu().numpy())
                        y_pred.extend(predicted.cpu().numpy())

                val_loss /= len(val_loader)
                scheduler.step(val_loss) # Adjust learning rate based on validation loss
                last_val_acc = (100.0 * val_correct / val_total) if val_total > 0 else 0.0
                y_true_last, y_pred_last = y_true, y_pred # Store for final F1 score calculation
                logger.info(f"Epoch {epoch}/{num_epochs} - Time: {epoch_times[-1]:.2f}s - Val Loss: {val_loss:.4f} - Val Acc: {last_val_acc:.2f}%")

                if last_val_acc > best_val_acc:
                    best_val_acc = last_val_acc
                    torch.save(model.state_dict(), best_model_path)
                    logger.info(f"New best model saved with validation accuracy: {best_val_acc:.2f}%")

            cuda_sync() # Ensure all GPU operations are complete before timing
            total_training_time = time.time() - train_start_time
            avg_time_per_epoch = np.mean(epoch_times)
            mem_current, mem_peak = get_gpu_memory() # Get GPU memory usage after training is complete to capture peak usage during training. Peak mem = max memory allocated at any point during training.
            final_f1 = sk_f1_score(y_true_last, y_pred_last, average='weighted')

            # ── Inference Timing on Validation Set ────
            model.eval()
            bench_batch, _ = next(iter(val_loader))
            bench_batch = bench_batch.to(device)
            single_img = bench_batch[:1]

            with torch.no_grad():
                # Warm-up - not measured during evaluation to ensure accurate timing
                cuda_sync()
                _ = model(single_img)
                cuda_sync()


                # Single image Latency - measured on a single image to capture the overhead of model loading and initial inference.
                # Averaged over 100 runs to get a stable estimate.
                _times = []
                for _ in range(100):
                    cuda_sync()
                    start_time = time.time()
                    _ = model(single_img)
                    cuda_sync()
                    _times.append(time.time() - start_time)
                lat_single = np.mean(_times)

                # Batch Latency - measured on a full batch to capture the model's performance under typical inference conditions.
                cuda_sync()
                start_time = time.time()
                _ = model(bench_batch)
                cuda_sync()
                lat_batch = time.time() - start_time
                throughput = len(bench_batch) / lat_batch if lat_batch > 0 else 0

            log_performance(
                model_name=MODEL_NAME,
                batch_size=batch_size,
                num_epochs=num_epochs,
                gpu_type=gpu_type,
                run_num=run,
                total_time=total_training_time,
                avg_epoch=avg_time_per_epoch,
                lat_single=lat_single,
                lat_batch=lat_batch,
                throughput=throughput,
                mem_used=mem_current,
                mem_peak=mem_peak,
                val_acc=last_val_acc,
                f1=final_f1 * 100  # Convert to percentage for logging
            )

logger.info(f"Completed all runs for {MODEL_NAME}. Performance metrics logged to {LOG_FILE}.")
logger.info(f'Best validation accuracy across all runs: {best_val_acc:.2f}%')
# Out:
# 2026-03-21 13:56:56,072 - INFO - GPU found: Tesla T4. Using GPU.
# INFO:__main__:GPU found: Tesla T4. Using GPU.
# 2026-03-21 13:56:56,074 - INFO - Beginning training and evaluation for CustomCNN on Device: cuda - GPU: Tesla T4
# INFO:__main__:Beginning training and evaluation for CustomCNN on Device: cuda - GPU: Tesla T4
# 2026-03-21 13:56:56,076 - INFO - Starting training and evaluation for CustomCNN across configurations.
# INFO:__main__:Starting training and evaluation for CustomCNN across configurations.
# 2026-03-21 13:56:56,079 - INFO - CustomCNN - Run 1/3 | Batch Size: 16 | Epochs: 5
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 16 | Epochs: 5
# 2026-03-21 13:57:36,380 - INFO - Epoch 1/5 - Time: 29.66s - Val Loss: 0.9683 - Val Acc: 55.71%
# INFO:__main__:Epoch 1/5 - Time: 29.66s - Val Loss: 0.9683 - Val Acc: 55.71%
# 2026-03-21 13:57:36,548 - INFO - New best model saved with validation accuracy: 55.71%
# INFO:__main__:New best model saved with validation accuracy: 55.71%
# 2026-03-21 13:58:10,976 - INFO - Epoch 2/5 - Time: 28.66s - Val Loss: 0.8827 - Val Acc: 61.07%
# INFO:__main__:Epoch 2/5 - Time: 28.66s - Val Loss: 0.8827 - Val Acc: 61.07%
# 2026-03-21 13:58:11,281 - INFO - New best model saved with validation accuracy: 61.07%
# INFO:__main__:New best model saved with validation accuracy: 61.07%
# 2026-03-21 13:58:43,948 - INFO - Epoch 3/5 - Time: 26.12s - Val Loss: 0.5760 - Val Acc: 77.86%
# INFO:__main__:Epoch 3/5 - Time: 26.12s - Val Loss: 0.5760 - Val Acc: 77.86%
# 2026-03-21 13:58:44,177 - INFO - New best model saved with validation accuracy: 77.86%
# INFO:__main__:New best model saved with validation accuracy: 77.86%
# 2026-03-21 13:59:16,852 - INFO - Epoch 4/5 - Time: 26.29s - Val Loss: 0.7258 - Val Acc: 72.77%
# INFO:__main__:Epoch 4/5 - Time: 26.29s - Val Loss: 0.7258 - Val Acc: 72.77%
# 2026-03-21 13:59:49,349 - INFO - Epoch 5/5 - Time: 26.74s - Val Loss: 0.5396 - Val Acc: 76.88%
# INFO:__main__:Epoch 5/5 - Time: 26.74s - Val Loss: 0.5396 - Val Acc: 76.88%
# 2026-03-21 13:59:49,922 - INFO - Logged performance for CustomCNN (Run 1) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 1) to performance_logs.csv
# 2026-03-21 13:59:49,924 - INFO -  Logged: bs=16 | epochs=5 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=5 | gpu=Tesla T4
# 2026-03-21 13:59:49,926 - INFO - CustomCNN - Run 2/3 | Batch Size: 16 | Epochs: 5
# INFO:__main__:CustomCNN - Run 2/3 | Batch Size: 16 | Epochs: 5
# 2026-03-21 14:00:23,998 - INFO - Epoch 1/5 - Time: 25.94s - Val Loss: 1.0724 - Val Acc: 47.23%
# INFO:__main__:Epoch 1/5 - Time: 25.94s - Val Loss: 1.0724 - Val Acc: 47.23%
# 2026-03-21 14:00:55,517 - INFO - Epoch 2/5 - Time: 25.70s - Val Loss: 0.9199 - Val Acc: 54.02%
# INFO:__main__:Epoch 2/5 - Time: 25.70s - Val Loss: 0.9199 - Val Acc: 54.02%
# 2026-03-21 14:01:28,165 - INFO - Epoch 3/5 - Time: 25.73s - Val Loss: 0.7710 - Val Acc: 66.79%
# INFO:__main__:Epoch 3/5 - Time: 25.73s - Val Loss: 0.7710 - Val Acc: 66.79%
# 2026-03-21 14:01:59,689 - INFO - Epoch 4/5 - Time: 25.74s - Val Loss: 0.7140 - Val Acc: 71.88%
# INFO:__main__:Epoch 4/5 - Time: 25.74s - Val Loss: 0.7140 - Val Acc: 71.88%
# 2026-03-21 14:02:32,792 - INFO - Epoch 5/5 - Time: 26.16s - Val Loss: 0.6440 - Val Acc: 73.66%
# INFO:__main__:Epoch 5/5 - Time: 26.16s - Val Loss: 0.6440 - Val Acc: 73.66%
# 2026-03-21 14:02:33,364 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 14:02:33,366 - INFO -  Logged: bs=16 | epochs=5 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=5 | gpu=Tesla T4
# 2026-03-21 14:02:33,368 - INFO - CustomCNN - Run 3/3 | Batch Size: 16 | Epochs: 5
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 16 | Epochs: 5
# 2026-03-21 14:03:05,867 - INFO - Epoch 1/5 - Time: 25.58s - Val Loss: 1.0895 - Val Acc: 56.61%
# INFO:__main__:Epoch 1/5 - Time: 25.58s - Val Loss: 1.0895 - Val Acc: 56.61%
# 2026-03-21 14:03:38,030 - INFO - Epoch 2/5 - Time: 25.29s - Val Loss: 0.8636 - Val Acc: 68.12%
# INFO:__main__:Epoch 2/5 - Time: 25.29s - Val Loss: 0.8636 - Val Acc: 68.12%
# 2026-03-21 14:04:09,653 - INFO - Epoch 3/5 - Time: 25.77s - Val Loss: 0.6309 - Val Acc: 75.71%
# INFO:__main__:Epoch 3/5 - Time: 25.77s - Val Loss: 0.6309 - Val Acc: 75.71%
# 2026-03-21 14:04:42,225 - INFO - Epoch 4/5 - Time: 25.65s - Val Loss: 0.6852 - Val Acc: 78.48%
# INFO:__main__:Epoch 4/5 - Time: 25.65s - Val Loss: 0.6852 - Val Acc: 78.48%
# 2026-03-21 14:04:42,450 - INFO - New best model saved with validation accuracy: 78.48%
# INFO:__main__:New best model saved with validation accuracy: 78.48%
# 2026-03-21 14:05:13,776 - INFO - Epoch 5/5 - Time: 25.55s - Val Loss: 0.5122 - Val Acc: 80.45%
# INFO:__main__:Epoch 5/5 - Time: 25.55s - Val Loss: 0.5122 - Val Acc: 80.45%
# 2026-03-21 14:05:13,998 - INFO - New best model saved with validation accuracy: 80.45%
# INFO:__main__:New best model saved with validation accuracy: 80.45%
# 2026-03-21 14:05:14,517 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 14:05:14,518 - INFO -  Logged: bs=16 | epochs=5 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=5 | gpu=Tesla T4
# 2026-03-21 14:05:14,519 - INFO - CustomCNN - Run 1/3 | Batch Size: 16 | Epochs: 10
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 16 | Epochs: 10
# 2026-03-21 14:05:47,793 - INFO - Epoch 1/10 - Time: 25.81s - Val Loss: 1.0144 - Val Acc: 56.70%
# INFO:__main__:Epoch 1/10 - Time: 25.81s - Val Loss: 1.0144 - Val Acc: 56.70%
# 2026-03-21 14:06:19,957 - INFO - Epoch 2/10 - Time: 25.81s - Val Loss: 0.9780 - Val Acc: 51.70%
# INFO:__main__:Epoch 2/10 - Time: 25.81s - Val Loss: 0.9780 - Val Acc: 51.70%
# 2026-03-21 14:06:52,181 - INFO - Epoch 3/10 - Time: 25.86s - Val Loss: 0.8369 - Val Acc: 70.00%
# INFO:__main__:Epoch 3/10 - Time: 25.86s - Val Loss: 0.8369 - Val Acc: 70.00%
# 2026-03-21 14:07:24,747 - INFO - Epoch 4/10 - Time: 25.91s - Val Loss: 0.7907 - Val Acc: 73.48%
# INFO:__main__:Epoch 4/10 - Time: 25.91s - Val Loss: 0.7907 - Val Acc: 73.48%
# 2026-03-21 14:07:56,550 - INFO - Epoch 5/10 - Time: 25.98s - Val Loss: 0.6462 - Val Acc: 72.95%
# INFO:__main__:Epoch 5/10 - Time: 25.98s - Val Loss: 0.6462 - Val Acc: 72.95%
# 2026-03-21 14:08:30,166 - INFO - Epoch 6/10 - Time: 26.30s - Val Loss: 0.5200 - Val Acc: 80.54%
# INFO:__main__:Epoch 6/10 - Time: 26.30s - Val Loss: 0.5200 - Val Acc: 80.54%
# 2026-03-21 14:08:30,397 - INFO - New best model saved with validation accuracy: 80.54%
# INFO:__main__:New best model saved with validation accuracy: 80.54%
# 2026-03-21 14:09:04,478 - INFO - Epoch 7/10 - Time: 27.94s - Val Loss: 0.5130 - Val Acc: 81.79%
# INFO:__main__:Epoch 7/10 - Time: 27.94s - Val Loss: 0.5130 - Val Acc: 81.79%
# 2026-03-21 14:09:04,710 - INFO - New best model saved with validation accuracy: 81.79%
# INFO:__main__:New best model saved with validation accuracy: 81.79%
# 2026-03-21 14:09:38,969 - INFO - Epoch 8/10 - Time: 26.96s - Val Loss: 0.4294 - Val Acc: 84.73%
# INFO:__main__:Epoch 8/10 - Time: 26.96s - Val Loss: 0.4294 - Val Acc: 84.73%
# 2026-03-21 14:09:39,199 - INFO - New best model saved with validation accuracy: 84.73%
# INFO:__main__:New best model saved with validation accuracy: 84.73%
# 2026-03-21 14:10:14,288 - INFO - Epoch 9/10 - Time: 27.74s - Val Loss: 0.4423 - Val Acc: 84.38%
# INFO:__main__:Epoch 9/10 - Time: 27.74s - Val Loss: 0.4423 - Val Acc: 84.38%
# 2026-03-21 14:10:48,224 - INFO - Epoch 10/10 - Time: 27.71s - Val Loss: 0.4157 - Val Acc: 86.16%
# INFO:__main__:Epoch 10/10 - Time: 27.71s - Val Loss: 0.4157 - Val Acc: 86.16%
# 2026-03-21 14:10:48,456 - INFO - New best model saved with validation accuracy: 86.16%
# INFO:__main__:New best model saved with validation accuracy: 86.16%
# 2026-03-21 14:10:49,005 - INFO - Logged performance for CustomCNN (Run 1) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 1) to performance_logs.csv
# 2026-03-21 14:10:49,008 - INFO -  Logged: bs=16 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=10 | gpu=Tesla T4
# 2026-03-21 14:10:49,010 - INFO - CustomCNN - Run 2/3 | Batch Size: 16 | Epochs: 10
# INFO:__main__:CustomCNN - Run 2/3 | Batch Size: 16 | Epochs: 10
# 2026-03-21 14:11:25,069 - INFO - Epoch 1/10 - Time: 28.46s - Val Loss: 1.0723 - Val Acc: 42.59%
# INFO:__main__:Epoch 1/10 - Time: 28.46s - Val Loss: 1.0723 - Val Acc: 42.59%
# 2026-03-21 14:11:59,758 - INFO - Epoch 2/10 - Time: 27.36s - Val Loss: 1.0484 - Val Acc: 54.11%
# INFO:__main__:Epoch 2/10 - Time: 27.36s - Val Loss: 1.0484 - Val Acc: 54.11%
# 2026-03-21 14:12:33,065 - INFO - Epoch 3/10 - Time: 27.27s - Val Loss: 0.8202 - Val Acc: 65.27%
# INFO:__main__:Epoch 3/10 - Time: 27.27s - Val Loss: 0.8202 - Val Acc: 65.27%
# 2026-03-21 14:13:07,418 - INFO - Epoch 4/10 - Time: 27.08s - Val Loss: 1.2984 - Val Acc: 48.21%
# INFO:__main__:Epoch 4/10 - Time: 27.08s - Val Loss: 1.2984 - Val Acc: 48.21%
# 2026-03-21 14:13:39,696 - INFO - Epoch 5/10 - Time: 26.38s - Val Loss: 0.6544 - Val Acc: 75.98%
# INFO:__main__:Epoch 5/10 - Time: 26.38s - Val Loss: 0.6544 - Val Acc: 75.98%
# 2026-03-21 14:14:13,154 - INFO - Epoch 6/10 - Time: 26.59s - Val Loss: 0.6044 - Val Acc: 77.50%
# INFO:__main__:Epoch 6/10 - Time: 26.59s - Val Loss: 0.6044 - Val Acc: 77.50%
# 2026-03-21 14:14:45,850 - INFO - Epoch 7/10 - Time: 26.10s - Val Loss: 0.6097 - Val Acc: 77.32%
# INFO:__main__:Epoch 7/10 - Time: 26.10s - Val Loss: 0.6097 - Val Acc: 77.32%
# 2026-03-21 14:15:18,776 - INFO - Epoch 8/10 - Time: 27.07s - Val Loss: 0.5101 - Val Acc: 83.04%
# INFO:__main__:Epoch 8/10 - Time: 27.07s - Val Loss: 0.5101 - Val Acc: 83.04%
# 2026-03-21 14:15:52,594 - INFO - Epoch 9/10 - Time: 26.77s - Val Loss: 0.5378 - Val Acc: 77.32%
# INFO:__main__:Epoch 9/10 - Time: 26.77s - Val Loss: 0.5378 - Val Acc: 77.32%
# 2026-03-21 14:16:25,303 - INFO - Epoch 10/10 - Time: 26.73s - Val Loss: 0.4351 - Val Acc: 83.66%
# INFO:__main__:Epoch 10/10 - Time: 26.73s - Val Loss: 0.4351 - Val Acc: 83.66%
# 2026-03-21 14:16:25,875 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 14:16:25,877 - INFO -  Logged: bs=16 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=10 | gpu=Tesla T4
# 2026-03-21 14:16:25,878 - INFO - CustomCNN - Run 3/3 | Batch Size: 16 | Epochs: 10
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 16 | Epochs: 10
# 2026-03-21 14:17:00,373 - INFO - Epoch 1/10 - Time: 26.71s - Val Loss: 1.0006 - Val Acc: 53.39%
# INFO:__main__:Epoch 1/10 - Time: 26.71s - Val Loss: 1.0006 - Val Acc: 53.39%
# 2026-03-21 14:17:33,178 - INFO - Epoch 2/10 - Time: 26.23s - Val Loss: 0.8367 - Val Acc: 68.93%
# INFO:__main__:Epoch 2/10 - Time: 26.23s - Val Loss: 0.8367 - Val Acc: 68.93%
# 2026-03-21 14:18:05,691 - INFO - Epoch 3/10 - Time: 26.24s - Val Loss: 0.7526 - Val Acc: 72.14%
# INFO:__main__:Epoch 3/10 - Time: 26.24s - Val Loss: 0.7526 - Val Acc: 72.14%
# 2026-03-21 14:18:39,513 - INFO - Epoch 4/10 - Time: 26.69s - Val Loss: 0.6070 - Val Acc: 76.79%
# INFO:__main__:Epoch 4/10 - Time: 26.69s - Val Loss: 0.6070 - Val Acc: 76.79%
# 2026-03-21 14:19:11,829 - INFO - Epoch 5/10 - Time: 26.39s - Val Loss: 1.0448 - Val Acc: 58.48%
# INFO:__main__:Epoch 5/10 - Time: 26.39s - Val Loss: 1.0448 - Val Acc: 58.48%
# 2026-03-21 14:19:45,408 - INFO - Epoch 6/10 - Time: 26.45s - Val Loss: 0.5515 - Val Acc: 80.98%
# INFO:__main__:Epoch 6/10 - Time: 26.45s - Val Loss: 0.5515 - Val Acc: 80.98%
# 2026-03-21 14:20:17,972 - INFO - Epoch 7/10 - Time: 26.64s - Val Loss: 0.4647 - Val Acc: 83.48%
# INFO:__main__:Epoch 7/10 - Time: 26.64s - Val Loss: 0.4647 - Val Acc: 83.48%
# 2026-03-21 14:20:51,908 - INFO - Epoch 8/10 - Time: 26.84s - Val Loss: 0.6610 - Val Acc: 77.68%
# INFO:__main__:Epoch 8/10 - Time: 26.84s - Val Loss: 0.6610 - Val Acc: 77.68%
# 2026-03-21 14:21:24,302 - INFO - Epoch 9/10 - Time: 26.50s - Val Loss: 0.6112 - Val Acc: 75.89%
# INFO:__main__:Epoch 9/10 - Time: 26.50s - Val Loss: 0.6112 - Val Acc: 75.89%
# 2026-03-21 14:21:58,674 - INFO - Epoch 10/10 - Time: 28.09s - Val Loss: 0.5119 - Val Acc: 79.38%
# INFO:__main__:Epoch 10/10 - Time: 28.09s - Val Loss: 0.5119 - Val Acc: 79.38%
# 2026-03-21 14:21:59,225 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 14:21:59,227 - INFO -  Logged: bs=16 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=10 | gpu=Tesla T4
# 2026-03-21 14:21:59,229 - INFO - CustomCNN - Run 1/3 | Batch Size: 16 | Epochs: 20
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 16 | Epochs: 20
# 2026-03-21 14:22:34,601 - INFO - Epoch 1/20 - Time: 27.11s - Val Loss: 1.1125 - Val Acc: 42.23%
# INFO:__main__:Epoch 1/20 - Time: 27.11s - Val Loss: 1.1125 - Val Acc: 42.23%
# 2026-03-21 14:23:07,575 - INFO - Epoch 2/20 - Time: 26.95s - Val Loss: 1.0438 - Val Acc: 55.89%
# INFO:__main__:Epoch 2/20 - Time: 26.95s - Val Loss: 1.0438 - Val Acc: 55.89%
# 2026-03-21 14:23:41,044 - INFO - Epoch 3/20 - Time: 26.39s - Val Loss: 1.0158 - Val Acc: 47.59%
# INFO:__main__:Epoch 3/20 - Time: 26.39s - Val Loss: 1.0158 - Val Acc: 47.59%
# 2026-03-21 14:24:13,982 - INFO - Epoch 4/20 - Time: 26.44s - Val Loss: 0.9189 - Val Acc: 60.00%
# INFO:__main__:Epoch 4/20 - Time: 26.44s - Val Loss: 0.9189 - Val Acc: 60.00%
# 2026-03-21 14:24:46,503 - INFO - Epoch 5/20 - Time: 26.37s - Val Loss: 0.6561 - Val Acc: 75.71%
# INFO:__main__:Epoch 5/20 - Time: 26.37s - Val Loss: 0.6561 - Val Acc: 75.71%
# 2026-03-21 14:25:21,001 - INFO - Epoch 6/20 - Time: 27.25s - Val Loss: 0.6834 - Val Acc: 75.27%
# INFO:__main__:Epoch 6/20 - Time: 27.25s - Val Loss: 0.6834 - Val Acc: 75.27%
# 2026-03-21 14:25:53,416 - INFO - Epoch 7/20 - Time: 26.52s - Val Loss: 0.5702 - Val Acc: 79.55%
# INFO:__main__:Epoch 7/20 - Time: 26.52s - Val Loss: 0.5702 - Val Acc: 79.55%
# 2026-03-21 14:26:27,029 - INFO - Epoch 8/20 - Time: 26.59s - Val Loss: 0.4963 - Val Acc: 79.55%
# INFO:__main__:Epoch 8/20 - Time: 26.59s - Val Loss: 0.4963 - Val Acc: 79.55%
# 2026-03-21 14:27:00,168 - INFO - Epoch 9/20 - Time: 26.84s - Val Loss: 0.4511 - Val Acc: 82.95%
# INFO:__main__:Epoch 9/20 - Time: 26.84s - Val Loss: 0.4511 - Val Acc: 82.95%
# 2026-03-21 14:27:35,255 - INFO - Epoch 10/20 - Time: 28.80s - Val Loss: 0.4597 - Val Acc: 83.12%
# INFO:__main__:Epoch 10/20 - Time: 28.80s - Val Loss: 0.4597 - Val Acc: 83.12%
# 2026-03-21 14:28:09,891 - INFO - Epoch 11/20 - Time: 27.32s - Val Loss: 0.3867 - Val Acc: 85.18%
# INFO:__main__:Epoch 11/20 - Time: 27.32s - Val Loss: 0.3867 - Val Acc: 85.18%
# 2026-03-21 14:28:42,730 - INFO - Epoch 12/20 - Time: 26.76s - Val Loss: 0.3885 - Val Acc: 85.80%
# INFO:__main__:Epoch 12/20 - Time: 26.76s - Val Loss: 0.3885 - Val Acc: 85.80%
# 2026-03-21 14:29:17,292 - INFO - Epoch 13/20 - Time: 27.44s - Val Loss: 0.3693 - Val Acc: 84.20%
# INFO:__main__:Epoch 13/20 - Time: 27.44s - Val Loss: 0.3693 - Val Acc: 84.20%
# 2026-03-21 14:29:50,819 - INFO - Epoch 14/20 - Time: 26.98s - Val Loss: 0.3341 - Val Acc: 86.96%
# INFO:__main__:Epoch 14/20 - Time: 26.98s - Val Loss: 0.3341 - Val Acc: 86.96%
# 2026-03-21 14:29:51,157 - INFO - New best model saved with validation accuracy: 86.96%
# INFO:__main__:New best model saved with validation accuracy: 86.96%
# 2026-03-21 14:30:24,307 - INFO - Epoch 15/20 - Time: 27.15s - Val Loss: 0.3374 - Val Acc: 86.61%
# INFO:__main__:Epoch 15/20 - Time: 27.15s - Val Loss: 0.3374 - Val Acc: 86.61%
# 2026-03-21 14:30:58,025 - INFO - Epoch 16/20 - Time: 26.53s - Val Loss: 0.2998 - Val Acc: 89.02%
# INFO:__main__:Epoch 16/20 - Time: 26.53s - Val Loss: 0.2998 - Val Acc: 89.02%
# 2026-03-21 14:30:58,256 - INFO - New best model saved with validation accuracy: 89.02%
# INFO:__main__:New best model saved with validation accuracy: 89.02%
# 2026-03-21 14:31:30,747 - INFO - Epoch 17/20 - Time: 26.61s - Val Loss: 0.3919 - Val Acc: 84.38%
# INFO:__main__:Epoch 17/20 - Time: 26.61s - Val Loss: 0.3919 - Val Acc: 84.38%
# 2026-03-21 14:32:04,339 - INFO - Epoch 18/20 - Time: 26.44s - Val Loss: 0.4714 - Val Acc: 83.39%
# INFO:__main__:Epoch 18/20 - Time: 26.44s - Val Loss: 0.4714 - Val Acc: 83.39%
# 2026-03-21 14:32:36,631 - INFO - Epoch 19/20 - Time: 26.31s - Val Loss: 0.2928 - Val Acc: 88.48%
# INFO:__main__:Epoch 19/20 - Time: 26.31s - Val Loss: 0.2928 - Val Acc: 88.48%
# 2026-03-21 14:33:10,326 - INFO - Epoch 20/20 - Time: 26.55s - Val Loss: 0.2752 - Val Acc: 88.75%
# INFO:__main__:Epoch 20/20 - Time: 26.55s - Val Loss: 0.2752 - Val Acc: 88.75%
# 2026-03-21 14:33:10,907 - INFO - Logged performance for CustomCNN (Run 1) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 1) to performance_logs.csv
# 2026-03-21 14:33:10,908 - INFO -  Logged: bs=16 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=20 | gpu=Tesla T4
# 2026-03-21 14:33:10,911 - INFO - CustomCNN - Run 2/3 | Batch Size: 16 | Epochs: 20
# INFO:__main__:CustomCNN - Run 2/3 | Batch Size: 16 | Epochs: 20
# 2026-03-21 14:33:46,275 - INFO - Epoch 1/20 - Time: 27.01s - Val Loss: 1.1097 - Val Acc: 50.00%
# INFO:__main__:Epoch 1/20 - Time: 27.01s - Val Loss: 1.1097 - Val Acc: 50.00%
# 2026-03-21 14:34:18,960 - INFO - Epoch 2/20 - Time: 26.69s - Val Loss: 0.9315 - Val Acc: 60.18%
# INFO:__main__:Epoch 2/20 - Time: 26.69s - Val Loss: 0.9315 - Val Acc: 60.18%
# 2026-03-21 14:34:52,762 - INFO - Epoch 3/20 - Time: 26.54s - Val Loss: 0.7945 - Val Acc: 70.62%
# INFO:__main__:Epoch 3/20 - Time: 26.54s - Val Loss: 0.7945 - Val Acc: 70.62%
# 2026-03-21 14:35:28,734 - INFO - Epoch 4/20 - Time: 28.46s - Val Loss: 0.9541 - Val Acc: 55.80%
# INFO:__main__:Epoch 4/20 - Time: 28.46s - Val Loss: 0.9541 - Val Acc: 55.80%
# 2026-03-21 14:36:02,522 - INFO - Epoch 5/20 - Time: 27.71s - Val Loss: 0.6963 - Val Acc: 71.07%
# INFO:__main__:Epoch 5/20 - Time: 27.71s - Val Loss: 0.6963 - Val Acc: 71.07%
# 2026-03-21 14:36:36,886 - INFO - Epoch 6/20 - Time: 27.20s - Val Loss: 0.5395 - Val Acc: 75.27%
# INFO:__main__:Epoch 6/20 - Time: 27.20s - Val Loss: 0.5395 - Val Acc: 75.27%
# 2026-03-21 14:37:09,864 - INFO - Epoch 7/20 - Time: 27.09s - Val Loss: 0.6235 - Val Acc: 76.16%
# INFO:__main__:Epoch 7/20 - Time: 27.09s - Val Loss: 0.6235 - Val Acc: 76.16%
# 2026-03-21 14:37:43,230 - INFO - Epoch 8/20 - Time: 26.48s - Val Loss: 0.4928 - Val Acc: 83.12%
# INFO:__main__:Epoch 8/20 - Time: 26.48s - Val Loss: 0.4928 - Val Acc: 83.12%
# 2026-03-21 14:38:16,909 - INFO - Epoch 9/20 - Time: 26.66s - Val Loss: 0.9408 - Val Acc: 58.48%
# INFO:__main__:Epoch 9/20 - Time: 26.66s - Val Loss: 0.9408 - Val Acc: 58.48%
# 2026-03-21 14:38:49,602 - INFO - Epoch 10/20 - Time: 26.79s - Val Loss: 0.6069 - Val Acc: 75.18%
# INFO:__main__:Epoch 10/20 - Time: 26.79s - Val Loss: 0.6069 - Val Acc: 75.18%
# 2026-03-21 14:39:23,193 - INFO - Epoch 11/20 - Time: 26.48s - Val Loss: 0.4465 - Val Acc: 83.21%
# INFO:__main__:Epoch 11/20 - Time: 26.48s - Val Loss: 0.4465 - Val Acc: 83.21%
# 2026-03-21 14:39:55,516 - INFO - Epoch 12/20 - Time: 26.35s - Val Loss: 0.3506 - Val Acc: 87.59%
# INFO:__main__:Epoch 12/20 - Time: 26.35s - Val Loss: 0.3506 - Val Acc: 87.59%
# 2026-03-21 14:40:29,239 - INFO - Epoch 13/20 - Time: 26.62s - Val Loss: 0.3198 - Val Acc: 88.48%
# INFO:__main__:Epoch 13/20 - Time: 26.62s - Val Loss: 0.3198 - Val Acc: 88.48%
# 2026-03-21 14:41:01,639 - INFO - Epoch 14/20 - Time: 26.48s - Val Loss: 0.3694 - Val Acc: 86.25%
# INFO:__main__:Epoch 14/20 - Time: 26.48s - Val Loss: 0.3694 - Val Acc: 86.25%
# 2026-03-21 14:41:35,294 - INFO - Epoch 15/20 - Time: 26.65s - Val Loss: 0.4624 - Val Acc: 83.75%
# INFO:__main__:Epoch 15/20 - Time: 26.65s - Val Loss: 0.4624 - Val Acc: 83.75%
# 2026-03-21 14:42:08,107 - INFO - Epoch 16/20 - Time: 26.20s - Val Loss: 0.3315 - Val Acc: 87.50%
# INFO:__main__:Epoch 16/20 - Time: 26.20s - Val Loss: 0.3315 - Val Acc: 87.50%
# 2026-03-21 14:42:41,830 - INFO - Epoch 17/20 - Time: 27.62s - Val Loss: 0.2915 - Val Acc: 89.20%
# INFO:__main__:Epoch 17/20 - Time: 27.62s - Val Loss: 0.2915 - Val Acc: 89.20%
# 2026-03-21 14:42:42,074 - INFO - New best model saved with validation accuracy: 89.20%
# INFO:__main__:New best model saved with validation accuracy: 89.20%
# 2026-03-21 14:43:15,997 - INFO - Epoch 18/20 - Time: 26.69s - Val Loss: 0.2663 - Val Acc: 89.29%
# INFO:__main__:Epoch 18/20 - Time: 26.69s - Val Loss: 0.2663 - Val Acc: 89.29%
# 2026-03-21 14:43:16,225 - INFO - New best model saved with validation accuracy: 89.29%
# INFO:__main__:New best model saved with validation accuracy: 89.29%
# 2026-03-21 14:43:49,019 - INFO - Epoch 19/20 - Time: 26.84s - Val Loss: 0.2636 - Val Acc: 90.54%
# INFO:__main__:Epoch 19/20 - Time: 26.84s - Val Loss: 0.2636 - Val Acc: 90.54%
# 2026-03-21 14:43:49,251 - INFO - New best model saved with validation accuracy: 90.54%
# INFO:__main__:New best model saved with validation accuracy: 90.54%
# 2026-03-21 14:44:23,281 - INFO - Epoch 20/20 - Time: 26.84s - Val Loss: 0.2480 - Val Acc: 90.45%
# INFO:__main__:Epoch 20/20 - Time: 26.84s - Val Loss: 0.2480 - Val Acc: 90.45%
# 2026-03-21 14:44:23,853 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 14:44:23,855 - INFO -  Logged: bs=16 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=20 | gpu=Tesla T4
# 2026-03-21 14:44:23,857 - INFO - CustomCNN - Run 3/3 | Batch Size: 16 | Epochs: 20
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 16 | Epochs: 20
# 2026-03-21 14:44:59,024 - INFO - Epoch 1/20 - Time: 26.86s - Val Loss: 0.9873 - Val Acc: 56.25%
# INFO:__main__:Epoch 1/20 - Time: 26.86s - Val Loss: 0.9873 - Val Acc: 56.25%
# 2026-03-21 14:45:31,558 - INFO - Epoch 2/20 - Time: 26.51s - Val Loss: 0.8952 - Val Acc: 63.57%
# INFO:__main__:Epoch 2/20 - Time: 26.51s - Val Loss: 0.8952 - Val Acc: 63.57%
# 2026-03-21 14:46:05,523 - INFO - Epoch 3/20 - Time: 26.73s - Val Loss: 0.9062 - Val Acc: 62.41%
# INFO:__main__:Epoch 3/20 - Time: 26.73s - Val Loss: 0.9062 - Val Acc: 62.41%
# 2026-03-21 14:46:38,317 - INFO - Epoch 4/20 - Time: 26.84s - Val Loss: 0.6875 - Val Acc: 75.89%
# INFO:__main__:Epoch 4/20 - Time: 26.84s - Val Loss: 0.6875 - Val Acc: 75.89%
# 2026-03-21 14:47:12,230 - INFO - Epoch 5/20 - Time: 27.37s - Val Loss: 0.7901 - Val Acc: 66.88%
# INFO:__main__:Epoch 5/20 - Time: 27.37s - Val Loss: 0.7901 - Val Acc: 66.88%
# 2026-03-21 14:47:45,921 - INFO - Epoch 6/20 - Time: 26.69s - Val Loss: 0.5443 - Val Acc: 81.79%
# INFO:__main__:Epoch 6/20 - Time: 26.69s - Val Loss: 0.5443 - Val Acc: 81.79%
# 2026-03-21 14:48:18,770 - INFO - Epoch 7/20 - Time: 26.96s - Val Loss: 0.4749 - Val Acc: 82.68%
# INFO:__main__:Epoch 7/20 - Time: 26.96s - Val Loss: 0.4749 - Val Acc: 82.68%
# 2026-03-21 14:48:53,132 - INFO - Epoch 8/20 - Time: 27.15s - Val Loss: 0.4588 - Val Acc: 82.95%
# INFO:__main__:Epoch 8/20 - Time: 27.15s - Val Loss: 0.4588 - Val Acc: 82.95%
# 2026-03-21 14:49:25,758 - INFO - Epoch 9/20 - Time: 26.71s - Val Loss: 0.4130 - Val Acc: 83.75%
# INFO:__main__:Epoch 9/20 - Time: 26.71s - Val Loss: 0.4130 - Val Acc: 83.75%
# 2026-03-21 14:49:59,686 - INFO - Epoch 10/20 - Time: 26.82s - Val Loss: 0.4199 - Val Acc: 85.71%
# INFO:__main__:Epoch 10/20 - Time: 26.82s - Val Loss: 0.4199 - Val Acc: 85.71%
# 2026-03-21 14:50:33,434 - INFO - Epoch 11/20 - Time: 26.95s - Val Loss: 0.3765 - Val Acc: 85.89%
# INFO:__main__:Epoch 11/20 - Time: 26.95s - Val Loss: 0.3765 - Val Acc: 85.89%
# 2026-03-21 14:51:06,526 - INFO - Epoch 12/20 - Time: 27.08s - Val Loss: 0.7751 - Val Acc: 70.54%
# INFO:__main__:Epoch 12/20 - Time: 27.08s - Val Loss: 0.7751 - Val Acc: 70.54%
# 2026-03-21 14:51:39,904 - INFO - Epoch 13/20 - Time: 26.19s - Val Loss: 0.3641 - Val Acc: 86.96%
# INFO:__main__:Epoch 13/20 - Time: 26.19s - Val Loss: 0.3641 - Val Acc: 86.96%
# 2026-03-21 14:52:12,291 - INFO - Epoch 14/20 - Time: 26.43s - Val Loss: 0.7461 - Val Acc: 69.64%
# INFO:__main__:Epoch 14/20 - Time: 26.43s - Val Loss: 0.7461 - Val Acc: 69.64%
# 2026-03-21 14:52:45,530 - INFO - Epoch 15/20 - Time: 26.11s - Val Loss: 0.4029 - Val Acc: 84.82%
# INFO:__main__:Epoch 15/20 - Time: 26.11s - Val Loss: 0.4029 - Val Acc: 84.82%
# 2026-03-21 14:53:18,146 - INFO - Epoch 16/20 - Time: 26.76s - Val Loss: 0.2800 - Val Acc: 90.00%
# INFO:__main__:Epoch 16/20 - Time: 26.76s - Val Loss: 0.2800 - Val Acc: 90.00%
# 2026-03-21 14:53:54,932 - INFO - Epoch 17/20 - Time: 30.80s - Val Loss: 0.2961 - Val Acc: 89.55%
# INFO:__main__:Epoch 17/20 - Time: 30.80s - Val Loss: 0.2961 - Val Acc: 89.55%
# 2026-03-21 14:54:28,701 - INFO - Epoch 18/20 - Time: 26.66s - Val Loss: 0.3039 - Val Acc: 88.04%
# INFO:__main__:Epoch 18/20 - Time: 26.66s - Val Loss: 0.3039 - Val Acc: 88.04%
# 2026-03-21 14:55:01,696 - INFO - Epoch 19/20 - Time: 27.03s - Val Loss: 0.2770 - Val Acc: 89.11%
# INFO:__main__:Epoch 19/20 - Time: 27.03s - Val Loss: 0.2770 - Val Acc: 89.11%
# 2026-03-21 14:55:36,774 - INFO - Epoch 20/20 - Time: 28.30s - Val Loss: 0.2399 - Val Acc: 91.43%
# INFO:__main__:Epoch 20/20 - Time: 28.30s - Val Loss: 0.2399 - Val Acc: 91.43%
# 2026-03-21 14:55:37,014 - INFO - New best model saved with validation accuracy: 91.43%
# INFO:__main__:New best model saved with validation accuracy: 91.43%
# 2026-03-21 14:55:37,639 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 14:55:37,641 - INFO -  Logged: bs=16 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=16 | epochs=20 | gpu=Tesla T4
# 2026-03-21 14:55:37,643 - INFO - CustomCNN - Run 1/3 | Batch Size: 32 | Epochs: 5
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 32 | Epochs: 5
# 2026-03-21 14:56:11,967 - INFO - Epoch 1/5 - Time: 26.06s - Val Loss: 1.0628 - Val Acc: 57.41%
# INFO:__main__:Epoch 1/5 - Time: 26.06s - Val Loss: 1.0628 - Val Acc: 57.41%
# 2026-03-21 14:56:44,181 - INFO - Epoch 2/5 - Time: 26.16s - Val Loss: 0.8828 - Val Acc: 63.48%
# INFO:__main__:Epoch 2/5 - Time: 26.16s - Val Loss: 0.8828 - Val Acc: 63.48%
# 2026-03-21 14:57:17,406 - INFO - Epoch 3/5 - Time: 26.10s - Val Loss: 0.9886 - Val Acc: 57.77%
# INFO:__main__:Epoch 3/5 - Time: 26.10s - Val Loss: 0.9886 - Val Acc: 57.77%
# 2026-03-21 14:57:49,171 - INFO - Epoch 4/5 - Time: 25.73s - Val Loss: 0.6432 - Val Acc: 74.64%
# INFO:__main__:Epoch 4/5 - Time: 25.73s - Val Loss: 0.6432 - Val Acc: 74.64%
# 2026-03-21 14:58:22,730 - INFO - Epoch 5/5 - Time: 26.43s - Val Loss: 0.6966 - Val Acc: 71.88%
# INFO:__main__:Epoch 5/5 - Time: 26.43s - Val Loss: 0.6966 - Val Acc: 71.88%
# 2026-03-21 14:58:23,637 - INFO - Logged performance for CustomCNN (Run 1) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 1) to performance_logs.csv
# 2026-03-21 14:58:23,639 - INFO -  Logged: bs=32 | epochs=5 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=5 | gpu=Tesla T4
# 2026-03-21 14:58:23,640 - INFO - CustomCNN - Run 2/3 | Batch Size: 32 | Epochs: 5
# INFO:__main__:CustomCNN - Run 2/3 | Batch Size: 32 | Epochs: 5
# 2026-03-21 14:58:57,325 - INFO - Epoch 1/5 - Time: 26.18s - Val Loss: 1.1083 - Val Acc: 45.89%
# INFO:__main__:Epoch 1/5 - Time: 26.18s - Val Loss: 1.1083 - Val Acc: 45.89%
# 2026-03-21 14:59:29,607 - INFO - Epoch 2/5 - Time: 26.06s - Val Loss: 0.9630 - Val Acc: 55.71%
# INFO:__main__:Epoch 2/5 - Time: 26.06s - Val Loss: 0.9630 - Val Acc: 55.71%
# 2026-03-21 15:00:03,244 - INFO - Epoch 3/5 - Time: 26.45s - Val Loss: 0.8553 - Val Acc: 66.96%
# INFO:__main__:Epoch 3/5 - Time: 26.45s - Val Loss: 0.8553 - Val Acc: 66.96%
# 2026-03-21 15:00:34,677 - INFO - Epoch 4/5 - Time: 25.52s - Val Loss: 0.7492 - Val Acc: 69.55%
# INFO:__main__:Epoch 4/5 - Time: 25.52s - Val Loss: 0.7492 - Val Acc: 69.55%
# 2026-03-21 15:01:07,815 - INFO - Epoch 5/5 - Time: 25.77s - Val Loss: 0.7095 - Val Acc: 70.54%
# INFO:__main__:Epoch 5/5 - Time: 25.77s - Val Loss: 0.7095 - Val Acc: 70.54%
# 2026-03-21 15:01:08,745 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 15:01:08,747 - INFO -  Logged: bs=32 | epochs=5 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=5 | gpu=Tesla T4
# 2026-03-21 15:01:08,748 - INFO - CustomCNN - Run 3/3 | Batch Size: 32 | Epochs: 5
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 32 | Epochs: 5
# 2026-03-21 15:01:42,744 - INFO - Epoch 1/5 - Time: 26.84s - Val Loss: 0.9512 - Val Acc: 55.89%
# INFO:__main__:Epoch 1/5 - Time: 26.84s - Val Loss: 0.9512 - Val Acc: 55.89%
# 2026-03-21 15:02:16,589 - INFO - Epoch 2/5 - Time: 26.59s - Val Loss: 0.8497 - Val Acc: 71.96%
# INFO:__main__:Epoch 2/5 - Time: 26.59s - Val Loss: 0.8497 - Val Acc: 71.96%
# 2026-03-21 15:02:50,575 - INFO - Epoch 3/5 - Time: 27.04s - Val Loss: 0.7775 - Val Acc: 60.18%
# INFO:__main__:Epoch 3/5 - Time: 27.04s - Val Loss: 0.7775 - Val Acc: 60.18%
# 2026-03-21 15:03:23,013 - INFO - Epoch 4/5 - Time: 26.25s - Val Loss: 0.5947 - Val Acc: 79.55%
# INFO:__main__:Epoch 4/5 - Time: 26.25s - Val Loss: 0.5947 - Val Acc: 79.55%
# 2026-03-21 15:03:56,980 - INFO - Epoch 5/5 - Time: 26.69s - Val Loss: 0.5653 - Val Acc: 78.04%
# INFO:__main__:Epoch 5/5 - Time: 26.69s - Val Loss: 0.5653 - Val Acc: 78.04%
# 2026-03-21 15:03:57,921 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 15:03:57,922 - INFO -  Logged: bs=32 | epochs=5 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=5 | gpu=Tesla T4
# 2026-03-21 15:03:57,925 - INFO - CustomCNN - Run 1/3 | Batch Size: 32 | Epochs: 10
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 32 | Epochs: 10
# 2026-03-21 15:04:31,188 - INFO - Epoch 1/10 - Time: 26.19s - Val Loss: 1.0692 - Val Acc: 51.52%
# INFO:__main__:Epoch 1/10 - Time: 26.19s - Val Loss: 1.0692 - Val Acc: 51.52%
# 2026-03-21 15:05:04,150 - INFO - Epoch 2/10 - Time: 25.73s - Val Loss: 0.9091 - Val Acc: 62.14%
# INFO:__main__:Epoch 2/10 - Time: 25.73s - Val Loss: 0.9091 - Val Acc: 62.14%
# 2026-03-21 15:05:36,672 - INFO - Epoch 3/10 - Time: 26.43s - Val Loss: 0.9839 - Val Acc: 54.02%
# INFO:__main__:Epoch 3/10 - Time: 26.43s - Val Loss: 0.9839 - Val Acc: 54.02%
# 2026-03-21 15:06:09,972 - INFO - Epoch 4/10 - Time: 27.13s - Val Loss: 0.7467 - Val Acc: 66.34%
# INFO:__main__:Epoch 4/10 - Time: 27.13s - Val Loss: 0.7467 - Val Acc: 66.34%
# 2026-03-21 15:06:43,930 - INFO - Epoch 5/10 - Time: 26.65s - Val Loss: 0.5797 - Val Acc: 76.61%
# INFO:__main__:Epoch 5/10 - Time: 26.65s - Val Loss: 0.5797 - Val Acc: 76.61%
# 2026-03-21 15:07:17,208 - INFO - Epoch 6/10 - Time: 27.24s - Val Loss: 1.0696 - Val Acc: 56.61%
# INFO:__main__:Epoch 6/10 - Time: 27.24s - Val Loss: 1.0696 - Val Acc: 56.61%
# 2026-03-21 15:07:51,156 - INFO - Epoch 7/10 - Time: 26.67s - Val Loss: 0.5279 - Val Acc: 79.38%
# INFO:__main__:Epoch 7/10 - Time: 26.67s - Val Loss: 0.5279 - Val Acc: 79.38%
# 2026-03-21 15:08:24,272 - INFO - Epoch 8/10 - Time: 26.97s - Val Loss: 1.0431 - Val Acc: 62.41%
# INFO:__main__:Epoch 8/10 - Time: 26.97s - Val Loss: 1.0431 - Val Acc: 62.41%
# 2026-03-21 15:08:57,437 - INFO - Epoch 9/10 - Time: 25.84s - Val Loss: 0.5067 - Val Acc: 82.23%
# INFO:__main__:Epoch 9/10 - Time: 25.84s - Val Loss: 0.5067 - Val Acc: 82.23%
# 2026-03-21 15:09:29,802 - INFO - Epoch 10/10 - Time: 26.10s - Val Loss: 0.8364 - Val Acc: 71.25%
# INFO:__main__:Epoch 10/10 - Time: 26.10s - Val Loss: 0.8364 - Val Acc: 71.25%
# 2026-03-21 15:09:31,292 - INFO - Logged performance for CustomCNN (Run 1) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 1) to performance_logs.csv
# 2026-03-21 15:09:31,295 - INFO -  Logged: bs=32 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=10 | gpu=Tesla T4
# 2026-03-21 15:09:31,297 - INFO - CustomCNN - Run 2/3 | Batch Size: 32 | Epochs: 10
# INFO:__main__:CustomCNN - Run 2/3 | Batch Size: 32 | Epochs: 10
# 2026-03-21 15:10:05,501 - INFO - Epoch 1/10 - Time: 26.82s - Val Loss: 1.0321 - Val Acc: 47.59%
# INFO:__main__:Epoch 1/10 - Time: 26.82s - Val Loss: 1.0321 - Val Acc: 47.59%
# 2026-03-21 15:10:39,137 - INFO - Epoch 2/10 - Time: 26.36s - Val Loss: 0.9033 - Val Acc: 57.77%
# INFO:__main__:Epoch 2/10 - Time: 26.36s - Val Loss: 0.9033 - Val Acc: 57.77%
# 2026-03-21 15:11:12,123 - INFO - Epoch 3/10 - Time: 27.07s - Val Loss: 0.9290 - Val Acc: 56.96%
# INFO:__main__:Epoch 3/10 - Time: 27.07s - Val Loss: 0.9290 - Val Acc: 56.96%
# 2026-03-21 15:11:46,271 - INFO - Epoch 4/10 - Time: 27.29s - Val Loss: 0.6765 - Val Acc: 73.04%
# INFO:__main__:Epoch 4/10 - Time: 27.29s - Val Loss: 0.6765 - Val Acc: 73.04%
# 2026-03-21 15:12:18,731 - INFO - Epoch 5/10 - Time: 26.01s - Val Loss: 0.7180 - Val Acc: 69.55%
# INFO:__main__:Epoch 5/10 - Time: 26.01s - Val Loss: 0.7180 - Val Acc: 69.55%
# 2026-03-21 15:12:51,523 - INFO - Epoch 6/10 - Time: 26.07s - Val Loss: 0.5007 - Val Acc: 82.77%
# INFO:__main__:Epoch 6/10 - Time: 26.07s - Val Loss: 0.5007 - Val Acc: 82.77%
# 2026-03-21 15:13:25,747 - INFO - Epoch 7/10 - Time: 26.96s - Val Loss: 0.5047 - Val Acc: 81.25%
# INFO:__main__:Epoch 7/10 - Time: 26.96s - Val Loss: 0.5047 - Val Acc: 81.25%
# 2026-03-21 15:13:57,591 - INFO - Epoch 8/10 - Time: 25.79s - Val Loss: 0.3818 - Val Acc: 85.18%
# INFO:__main__:Epoch 8/10 - Time: 25.79s - Val Loss: 0.3818 - Val Acc: 85.18%
# 2026-03-21 15:14:30,981 - INFO - Epoch 9/10 - Time: 26.15s - Val Loss: 0.6865 - Val Acc: 70.89%
# INFO:__main__:Epoch 9/10 - Time: 26.15s - Val Loss: 0.6865 - Val Acc: 70.89%
# 2026-03-21 15:15:04,051 - INFO - Epoch 10/10 - Time: 26.95s - Val Loss: 0.4954 - Val Acc: 81.25%
# INFO:__main__:Epoch 10/10 - Time: 26.95s - Val Loss: 0.4954 - Val Acc: 81.25%
# 2026-03-21 15:15:04,982 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 15:15:04,984 - INFO -  Logged: bs=32 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=10 | gpu=Tesla T4
# 2026-03-21 15:15:04,986 - INFO - CustomCNN - Run 3/3 | Batch Size: 32 | Epochs: 10
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 32 | Epochs: 10
# 2026-03-21 15:15:38,603 - INFO - Epoch 1/10 - Time: 25.69s - Val Loss: 1.0704 - Val Acc: 44.55%
# INFO:__main__:Epoch 1/10 - Time: 25.69s - Val Loss: 1.0704 - Val Acc: 44.55%
# 2026-03-21 15:16:12,854 - INFO - Epoch 2/10 - Time: 27.12s - Val Loss: 0.9817 - Val Acc: 60.27%
# INFO:__main__:Epoch 2/10 - Time: 27.12s - Val Loss: 0.9817 - Val Acc: 60.27%
# 2026-03-21 15:16:44,712 - INFO - Epoch 3/10 - Time: 25.90s - Val Loss: 0.8658 - Val Acc: 66.61%
# INFO:__main__:Epoch 3/10 - Time: 25.90s - Val Loss: 0.8658 - Val Acc: 66.61%
# 2026-03-21 15:17:17,992 - INFO - Epoch 4/10 - Time: 26.14s - Val Loss: 0.7572 - Val Acc: 70.00%
# INFO:__main__:Epoch 4/10 - Time: 26.14s - Val Loss: 0.7572 - Val Acc: 70.00%
# 2026-03-21 15:17:50,758 - INFO - Epoch 5/10 - Time: 26.82s - Val Loss: 0.6540 - Val Acc: 76.43%
# INFO:__main__:Epoch 5/10 - Time: 26.82s - Val Loss: 0.6540 - Val Acc: 76.43%
# 2026-03-21 15:18:24,798 - INFO - Epoch 6/10 - Time: 26.72s - Val Loss: 0.5594 - Val Acc: 81.16%
# INFO:__main__:Epoch 6/10 - Time: 26.72s - Val Loss: 0.5594 - Val Acc: 81.16%
# 2026-03-21 15:18:56,916 - INFO - Epoch 7/10 - Time: 26.19s - Val Loss: 0.5055 - Val Acc: 81.25%
# INFO:__main__:Epoch 7/10 - Time: 26.19s - Val Loss: 0.5055 - Val Acc: 81.25%
# 2026-03-21 15:19:30,593 - INFO - Epoch 8/10 - Time: 26.57s - Val Loss: 0.5229 - Val Acc: 80.45%
# INFO:__main__:Epoch 8/10 - Time: 26.57s - Val Loss: 0.5229 - Val Acc: 80.45%
# 2026-03-21 15:20:04,549 - INFO - Epoch 9/10 - Time: 26.80s - Val Loss: 0.4235 - Val Acc: 81.52%
# INFO:__main__:Epoch 9/10 - Time: 26.80s - Val Loss: 0.4235 - Val Acc: 81.52%
# 2026-03-21 15:20:36,767 - INFO - Epoch 10/10 - Time: 26.26s - Val Loss: 0.4137 - Val Acc: 84.11%
# INFO:__main__:Epoch 10/10 - Time: 26.26s - Val Loss: 0.4137 - Val Acc: 84.11%
# 2026-03-21 15:20:37,723 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 15:20:37,725 - INFO -  Logged: bs=32 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=10 | gpu=Tesla T4
# 2026-03-21 15:20:37,726 - INFO - CustomCNN - Run 1/3 | Batch Size: 32 | Epochs: 20
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 32 | Epochs: 20
# 2026-03-21 15:21:12,390 - INFO - Epoch 1/20 - Time: 26.23s - Val Loss: 1.0118 - Val Acc: 61.52%
# INFO:__main__:Epoch 1/20 - Time: 26.23s - Val Loss: 1.0118 - Val Acc: 61.52%
# 2026-03-21 15:21:43,924 - INFO - Epoch 2/20 - Time: 25.47s - Val Loss: 0.8908 - Val Acc: 62.59%
# INFO:__main__:Epoch 2/20 - Time: 25.47s - Val Loss: 0.8908 - Val Acc: 62.59%
# 2026-03-21 15:22:18,120 - INFO - Epoch 3/20 - Time: 26.92s - Val Loss: 0.7677 - Val Acc: 76.61%
# INFO:__main__:Epoch 3/20 - Time: 26.92s - Val Loss: 0.7677 - Val Acc: 76.61%
# 2026-03-21 15:22:50,495 - INFO - Epoch 4/20 - Time: 26.18s - Val Loss: 0.6946 - Val Acc: 71.61%
# INFO:__main__:Epoch 4/20 - Time: 26.18s - Val Loss: 0.6946 - Val Acc: 71.61%
# 2026-03-21 15:23:23,198 - INFO - Epoch 5/20 - Time: 25.63s - Val Loss: 0.6788 - Val Acc: 76.96%
# INFO:__main__:Epoch 5/20 - Time: 25.63s - Val Loss: 0.6788 - Val Acc: 76.96%
# 2026-03-21 15:23:55,837 - INFO - Epoch 6/20 - Time: 26.04s - Val Loss: 0.6876 - Val Acc: 72.41%
# INFO:__main__:Epoch 6/20 - Time: 26.04s - Val Loss: 0.6876 - Val Acc: 72.41%
# 2026-03-21 15:24:28,917 - INFO - Epoch 7/20 - Time: 26.92s - Val Loss: 0.4980 - Val Acc: 83.75%
# INFO:__main__:Epoch 7/20 - Time: 26.92s - Val Loss: 0.4980 - Val Acc: 83.75%
# 2026-03-21 15:25:03,008 - INFO - Epoch 8/20 - Time: 26.76s - Val Loss: 0.7768 - Val Acc: 67.50%
# INFO:__main__:Epoch 8/20 - Time: 26.76s - Val Loss: 0.7768 - Val Acc: 67.50%
# 2026-03-21 15:25:34,431 - INFO - Epoch 9/20 - Time: 25.50s - Val Loss: 1.6933 - Val Acc: 54.82%
# INFO:__main__:Epoch 9/20 - Time: 25.50s - Val Loss: 1.6933 - Val Acc: 54.82%
# 2026-03-21 15:26:08,290 - INFO - Epoch 10/20 - Time: 26.68s - Val Loss: 1.0176 - Val Acc: 60.36%
# INFO:__main__:Epoch 10/20 - Time: 26.68s - Val Loss: 1.0176 - Val Acc: 60.36%
# 2026-03-21 15:26:40,577 - INFO - Epoch 11/20 - Time: 26.32s - Val Loss: 0.7538 - Val Acc: 71.43%
# INFO:__main__:Epoch 11/20 - Time: 26.32s - Val Loss: 0.7538 - Val Acc: 71.43%
# 2026-03-21 15:27:13,801 - INFO - Epoch 12/20 - Time: 26.06s - Val Loss: 0.3555 - Val Acc: 86.61%
# INFO:__main__:Epoch 12/20 - Time: 26.06s - Val Loss: 0.3555 - Val Acc: 86.61%
# 2026-03-21 15:27:46,309 - INFO - Epoch 13/20 - Time: 26.61s - Val Loss: 0.3201 - Val Acc: 87.86%
# INFO:__main__:Epoch 13/20 - Time: 26.61s - Val Loss: 0.3201 - Val Acc: 87.86%
# 2026-03-21 15:28:19,372 - INFO - Epoch 14/20 - Time: 25.97s - Val Loss: 0.3138 - Val Acc: 88.48%
# INFO:__main__:Epoch 14/20 - Time: 25.97s - Val Loss: 0.3138 - Val Acc: 88.48%
# 2026-03-21 15:28:51,486 - INFO - Epoch 15/20 - Time: 26.15s - Val Loss: 0.3122 - Val Acc: 88.84%
# INFO:__main__:Epoch 15/20 - Time: 26.15s - Val Loss: 0.3122 - Val Acc: 88.84%
# 2026-03-21 15:29:24,505 - INFO - Epoch 16/20 - Time: 25.78s - Val Loss: 0.3008 - Val Acc: 89.73%
# INFO:__main__:Epoch 16/20 - Time: 25.78s - Val Loss: 0.3008 - Val Acc: 89.73%
# 2026-03-21 15:29:56,111 - INFO - Epoch 17/20 - Time: 25.59s - Val Loss: 0.2996 - Val Acc: 88.93%
# INFO:__main__:Epoch 17/20 - Time: 25.59s - Val Loss: 0.2996 - Val Acc: 88.93%
# 2026-03-21 15:30:30,165 - INFO - Epoch 18/20 - Time: 27.00s - Val Loss: 0.3195 - Val Acc: 87.68%
# INFO:__main__:Epoch 18/20 - Time: 27.00s - Val Loss: 0.3195 - Val Acc: 87.68%
# 2026-03-21 15:31:04,626 - INFO - Epoch 19/20 - Time: 27.20s - Val Loss: 0.3018 - Val Acc: 88.84%
# INFO:__main__:Epoch 19/20 - Time: 27.20s - Val Loss: 0.3018 - Val Acc: 88.84%
# 2026-03-21 15:31:36,970 - INFO - Epoch 20/20 - Time: 26.29s - Val Loss: 0.2703 - Val Acc: 89.55%
# INFO:__main__:Epoch 20/20 - Time: 26.29s - Val Loss: 0.2703 - Val Acc: 89.55%
# 2026-03-21 15:31:37,909 - INFO - Logged performance for CustomCNN (Run 1) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 1) to performance_logs.csv
# 2026-03-21 15:31:37,911 - INFO -  Logged: bs=32 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=20 | gpu=Tesla T4
# 2026-03-21 15:31:37,913 - INFO - CustomCNN - Run 2/3 | Batch Size: 32 | Epochs: 20
# INFO:__main__:CustomCNN - Run 2/3 | Batch Size: 32 | Epochs: 20
# 2026-03-21 15:32:12,834 - INFO - Epoch 1/20 - Time: 26.73s - Val Loss: 0.9296 - Val Acc: 59.64%
# INFO:__main__:Epoch 1/20 - Time: 26.73s - Val Loss: 0.9296 - Val Acc: 59.64%
# 2026-03-21 15:32:44,971 - INFO - Epoch 2/20 - Time: 26.25s - Val Loss: 0.7920 - Val Acc: 70.54%
# INFO:__main__:Epoch 2/20 - Time: 26.25s - Val Loss: 0.7920 - Val Acc: 70.54%
# 2026-03-21 15:33:18,944 - INFO - Epoch 3/20 - Time: 27.21s - Val Loss: 0.6921 - Val Acc: 74.20%
# INFO:__main__:Epoch 3/20 - Time: 27.21s - Val Loss: 0.6921 - Val Acc: 74.20%
# 2026-03-21 15:33:52,862 - INFO - Epoch 4/20 - Time: 27.00s - Val Loss: 0.5933 - Val Acc: 77.32%
# INFO:__main__:Epoch 4/20 - Time: 27.00s - Val Loss: 0.5933 - Val Acc: 77.32%
# 2026-03-21 15:34:25,157 - INFO - Epoch 5/20 - Time: 26.39s - Val Loss: 0.9913 - Val Acc: 57.86%
# INFO:__main__:Epoch 5/20 - Time: 26.39s - Val Loss: 0.9913 - Val Acc: 57.86%
# 2026-03-21 15:34:58,828 - INFO - Epoch 6/20 - Time: 26.33s - Val Loss: 0.5006 - Val Acc: 81.25%
# INFO:__main__:Epoch 6/20 - Time: 26.33s - Val Loss: 0.5006 - Val Acc: 81.25%
# 2026-03-21 15:35:32,143 - INFO - Epoch 7/20 - Time: 27.21s - Val Loss: 0.5443 - Val Acc: 83.30%
# INFO:__main__:Epoch 7/20 - Time: 27.21s - Val Loss: 0.5443 - Val Acc: 83.30%
# 2026-03-21 15:36:05,896 - INFO - Epoch 8/20 - Time: 26.48s - Val Loss: 0.4244 - Val Acc: 85.54%
# INFO:__main__:Epoch 8/20 - Time: 26.48s - Val Loss: 0.4244 - Val Acc: 85.54%
# 2026-03-21 15:36:37,582 - INFO - Epoch 9/20 - Time: 25.88s - Val Loss: 0.3920 - Val Acc: 86.25%
# INFO:__main__:Epoch 9/20 - Time: 25.88s - Val Loss: 0.3920 - Val Acc: 86.25%
# 2026-03-21 15:37:11,515 - INFO - Epoch 10/20 - Time: 26.82s - Val Loss: 0.4358 - Val Acc: 83.57%
# INFO:__main__:Epoch 10/20 - Time: 26.82s - Val Loss: 0.4358 - Val Acc: 83.57%
# 2026-03-21 15:37:44,744 - INFO - Epoch 11/20 - Time: 26.86s - Val Loss: 1.1676 - Val Acc: 64.02%
# INFO:__main__:Epoch 11/20 - Time: 26.86s - Val Loss: 1.1676 - Val Acc: 64.02%
# 2026-03-21 15:38:18,048 - INFO - Epoch 12/20 - Time: 27.13s - Val Loss: 0.3639 - Val Acc: 86.70%
# INFO:__main__:Epoch 12/20 - Time: 27.13s - Val Loss: 0.3639 - Val Acc: 86.70%
# 2026-03-21 15:38:50,720 - INFO - Epoch 13/20 - Time: 26.05s - Val Loss: 0.3721 - Val Acc: 86.52%
# INFO:__main__:Epoch 13/20 - Time: 26.05s - Val Loss: 0.3721 - Val Acc: 86.52%
# 2026-03-21 15:39:23,204 - INFO - Epoch 14/20 - Time: 26.19s - Val Loss: 0.3663 - Val Acc: 86.34%
# INFO:__main__:Epoch 14/20 - Time: 26.19s - Val Loss: 0.3663 - Val Acc: 86.34%
# 2026-03-21 15:39:56,784 - INFO - Epoch 15/20 - Time: 26.45s - Val Loss: 0.3097 - Val Acc: 88.84%
# INFO:__main__:Epoch 15/20 - Time: 26.45s - Val Loss: 0.3097 - Val Acc: 88.84%
# 2026-03-21 15:40:28,283 - INFO - Epoch 16/20 - Time: 25.59s - Val Loss: 0.2998 - Val Acc: 88.57%
# INFO:__main__:Epoch 16/20 - Time: 25.59s - Val Loss: 0.2998 - Val Acc: 88.57%
# 2026-03-21 15:41:02,063 - INFO - Epoch 17/20 - Time: 26.56s - Val Loss: 0.2792 - Val Acc: 89.38%
# INFO:__main__:Epoch 17/20 - Time: 26.56s - Val Loss: 0.2792 - Val Acc: 89.38%
# 2026-03-21 15:41:34,771 - INFO - Epoch 18/20 - Time: 26.70s - Val Loss: 0.2782 - Val Acc: 89.11%
# INFO:__main__:Epoch 18/20 - Time: 26.70s - Val Loss: 0.2782 - Val Acc: 89.11%
# 2026-03-21 15:42:08,828 - INFO - Epoch 19/20 - Time: 26.76s - Val Loss: 0.2897 - Val Acc: 88.84%
# INFO:__main__:Epoch 19/20 - Time: 26.76s - Val Loss: 0.2897 - Val Acc: 88.84%
# 2026-03-21 15:42:41,236 - INFO - Epoch 20/20 - Time: 26.34s - Val Loss: 0.2434 - Val Acc: 89.91%
# INFO:__main__:Epoch 20/20 - Time: 26.34s - Val Loss: 0.2434 - Val Acc: 89.91%
# 2026-03-21 15:42:42,163 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 15:42:42,165 - INFO -  Logged: bs=32 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=20 | gpu=Tesla T4
# 2026-03-21 15:42:42,168 - INFO - CustomCNN - Run 3/3 | Batch Size: 32 | Epochs: 20
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 32 | Epochs: 20
# 2026-03-21 15:43:16,911 - INFO - Epoch 1/20 - Time: 27.21s - Val Loss: 1.0417 - Val Acc: 53.75%
# INFO:__main__:Epoch 1/20 - Time: 27.21s - Val Loss: 1.0417 - Val Acc: 53.75%
# 2026-03-21 15:43:51,145 - INFO - Epoch 2/20 - Time: 27.00s - Val Loss: 0.9443 - Val Acc: 61.61%
# INFO:__main__:Epoch 2/20 - Time: 27.00s - Val Loss: 0.9443 - Val Acc: 61.61%
# 2026-03-21 15:44:24,364 - INFO - Epoch 3/20 - Time: 27.23s - Val Loss: 0.7897 - Val Acc: 66.16%
# INFO:__main__:Epoch 3/20 - Time: 27.23s - Val Loss: 0.7897 - Val Acc: 66.16%
# 2026-03-21 15:44:58,281 - INFO - Epoch 4/20 - Time: 26.72s - Val Loss: 0.7650 - Val Acc: 66.88%
# INFO:__main__:Epoch 4/20 - Time: 26.72s - Val Loss: 0.7650 - Val Acc: 66.88%
# 2026-03-21 15:45:30,285 - INFO - Epoch 5/20 - Time: 25.94s - Val Loss: 0.6248 - Val Acc: 75.18%
# INFO:__main__:Epoch 5/20 - Time: 25.94s - Val Loss: 0.6248 - Val Acc: 75.18%
# 2026-03-21 15:46:03,519 - INFO - Epoch 6/20 - Time: 25.92s - Val Loss: 0.5486 - Val Acc: 82.41%
# INFO:__main__:Epoch 6/20 - Time: 25.92s - Val Loss: 0.5486 - Val Acc: 82.41%
# 2026-03-21 15:46:36,580 - INFO - Epoch 7/20 - Time: 27.02s - Val Loss: 0.7330 - Val Acc: 68.04%
# INFO:__main__:Epoch 7/20 - Time: 27.02s - Val Loss: 0.7330 - Val Acc: 68.04%
# 2026-03-21 15:47:09,363 - INFO - Epoch 8/20 - Time: 25.99s - Val Loss: 2.6263 - Val Acc: 38.39%
# INFO:__main__:Epoch 8/20 - Time: 25.99s - Val Loss: 2.6263 - Val Acc: 38.39%
# 2026-03-21 15:47:41,697 - INFO - Epoch 9/20 - Time: 26.19s - Val Loss: 0.4588 - Val Acc: 82.86%
# INFO:__main__:Epoch 9/20 - Time: 26.19s - Val Loss: 0.4588 - Val Acc: 82.86%
# 2026-03-21 15:48:14,107 - INFO - Epoch 10/20 - Time: 25.78s - Val Loss: 1.0568 - Val Acc: 67.32%
# INFO:__main__:Epoch 10/20 - Time: 25.78s - Val Loss: 1.0568 - Val Acc: 67.32%
# 2026-03-21 15:48:46,094 - INFO - Epoch 11/20 - Time: 25.79s - Val Loss: 0.3795 - Val Acc: 87.05%
# INFO:__main__:Epoch 11/20 - Time: 25.79s - Val Loss: 0.3795 - Val Acc: 87.05%
# 2026-03-21 15:49:19,597 - INFO - Epoch 12/20 - Time: 27.01s - Val Loss: 0.4322 - Val Acc: 84.38%
# INFO:__main__:Epoch 12/20 - Time: 27.01s - Val Loss: 0.4322 - Val Acc: 84.38%
# 2026-03-21 15:49:52,943 - INFO - Epoch 13/20 - Time: 26.17s - Val Loss: 0.4421 - Val Acc: 84.46%
# INFO:__main__:Epoch 13/20 - Time: 26.17s - Val Loss: 0.4421 - Val Acc: 84.46%
# 2026-03-21 15:50:25,724 - INFO - Epoch 14/20 - Time: 26.83s - Val Loss: 0.3906 - Val Acc: 86.07%
# INFO:__main__:Epoch 14/20 - Time: 26.83s - Val Loss: 0.3906 - Val Acc: 86.07%
# 2026-03-21 15:51:00,002 - INFO - Epoch 15/20 - Time: 27.01s - Val Loss: 0.3196 - Val Acc: 88.21%
# INFO:__main__:Epoch 15/20 - Time: 27.01s - Val Loss: 0.3196 - Val Acc: 88.21%
# 2026-03-21 15:51:32,280 - INFO - Epoch 16/20 - Time: 26.40s - Val Loss: 0.5115 - Val Acc: 82.14%
# INFO:__main__:Epoch 16/20 - Time: 26.40s - Val Loss: 0.5115 - Val Acc: 82.14%
# 2026-03-21 15:52:05,379 - INFO - Epoch 17/20 - Time: 26.03s - Val Loss: 0.7679 - Val Acc: 78.04%
# INFO:__main__:Epoch 17/20 - Time: 26.03s - Val Loss: 0.7679 - Val Acc: 78.04%
# 2026-03-21 15:52:36,726 - INFO - Epoch 18/20 - Time: 25.37s - Val Loss: 0.3491 - Val Acc: 88.12%
# INFO:__main__:Epoch 18/20 - Time: 25.37s - Val Loss: 0.3491 - Val Acc: 88.12%
# 2026-03-21 15:53:09,901 - INFO - Epoch 19/20 - Time: 26.02s - Val Loss: 0.5130 - Val Acc: 83.21%
# INFO:__main__:Epoch 19/20 - Time: 26.02s - Val Loss: 0.5130 - Val Acc: 83.21%
# 2026-03-21 15:53:41,638 - INFO - Epoch 20/20 - Time: 25.83s - Val Loss: 0.2342 - Val Acc: 91.96%
# INFO:__main__:Epoch 20/20 - Time: 25.83s - Val Loss: 0.2342 - Val Acc: 91.96%
# 2026-03-21 15:53:41,868 - INFO - New best model saved with validation accuracy: 91.96%
# INFO:__main__:New best model saved with validation accuracy: 91.96%
# 2026-03-21 15:53:42,776 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 15:53:42,777 - INFO -  Logged: bs=32 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=32 | epochs=20 | gpu=Tesla T4
# 2026-03-21 15:53:42,779 - INFO - CustomCNN - Run 1/3 | Batch Size: 64 | Epochs: 5
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 64 | Epochs: 5
# 2026-03-21 15:54:16,586 - INFO - Epoch 1/5 - Time: 26.16s - Val Loss: 0.9563 - Val Acc: 60.80%
# INFO:__main__:Epoch 1/5 - Time: 26.16s - Val Loss: 0.9563 - Val Acc: 60.80%
# ...
# INFO:__main__:Epoch 3/10 - Time: 26.28s - Val Loss: 0.8109 - Val Acc: 64.46%
# 2026-03-21 16:09:29,340 - INFO - Epoch 4/10 - Time: 26.60s - Val Loss: 0.6919 - Val Acc: 73.84%
# INFO:__main__:Epoch 4/10 - Time: 26.60s - Val Loss: 0.6919 - Val Acc: 73.84%
# 2026-03-21 16:10:00,404 - INFO - Epoch 5/10 - Time: 25.18s - Val Loss: 0.6470 - Val Acc: 73.12%
# INFO:__main__:Epoch 5/10 - Time: 25.18s - Val Loss: 0.6470 - Val Acc: 73.12%
# 2026-03-21 16:10:32,685 - INFO - Epoch 6/10 - Time: 25.23s - Val Loss: 2.7936 - Val Acc: 49.11%
# INFO:__main__:Epoch 6/10 - Time: 25.23s - Val Loss: 2.7936 - Val Acc: 49.11%
# 2026-03-21 16:11:04,305 - INFO - Epoch 7/10 - Time: 25.47s - Val Loss: 0.6502 - Val Acc: 76.61%
# INFO:__main__:Epoch 7/10 - Time: 25.47s - Val Loss: 0.6502 - Val Acc: 76.61%
# 2026-03-21 16:11:35,785 - INFO - Epoch 8/10 - Time: 25.14s - Val Loss: 0.4232 - Val Acc: 83.75%
# INFO:__main__:Epoch 8/10 - Time: 25.14s - Val Loss: 0.4232 - Val Acc: 83.75%
# 2026-03-21 16:12:09,304 - INFO - Epoch 9/10 - Time: 27.30s - Val Loss: 0.7501 - Val Acc: 72.77%
# INFO:__main__:Epoch 9/10 - Time: 27.30s - Val Loss: 0.7501 - Val Acc: 72.77%
# 2026-03-21 16:12:43,396 - INFO - Epoch 10/10 - Time: 26.85s - Val Loss: 0.4862 - Val Acc: 80.80%
# INFO:__main__:Epoch 10/10 - Time: 26.85s - Val Loss: 0.4862 - Val Acc: 80.80%
# 2026-03-21 16:12:44,965 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 16:12:44,967 - INFO -  Logged: bs=64 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=64 | epochs=10 | gpu=Tesla T4
# 2026-03-21 16:12:44,970 - INFO - CustomCNN - Run 3/3 | Batch Size: 64 | Epochs: 10
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 64 | Epochs: 10
# 2026-03-21 16:13:18,693 - INFO - Epoch 1/10 - Time: 26.60s - Val Loss: 1.0565 - Val Acc: 51.43%
# INFO:__main__:Epoch 1/10 - Time: 26.60s - Val Loss: 1.0565 - Val Acc: 51.43%
# 2026-03-21 16:13:52,962 - INFO - Epoch 2/10 - Time: 27.73s - Val Loss: 0.9119 - Val Acc: 66.07%
# INFO:__main__:Epoch 2/10 - Time: 27.73s - Val Loss: 0.9119 - Val Acc: 66.07%
# 2026-03-21 16:14:26,544 - INFO - Epoch 3/10 - Time: 26.46s - Val Loss: 0.7752 - Val Acc: 71.70%
# INFO:__main__:Epoch 3/10 - Time: 26.46s - Val Loss: 0.7752 - Val Acc: 71.70%
# 2026-03-21 16:14:57,433 - INFO - Epoch 4/10 - Time: 24.83s - Val Loss: 0.7396 - Val Acc: 70.54%
# INFO:__main__:Epoch 4/10 - Time: 24.83s - Val Loss: 0.7396 - Val Acc: 70.54%
# 2026-03-21 16:15:28,420 - INFO - Epoch 5/10 - Time: 25.03s - Val Loss: 0.8629 - Val Acc: 59.20%
# INFO:__main__:Epoch 5/10 - Time: 25.03s - Val Loss: 0.8629 - Val Acc: 59.20%
# 2026-03-21 16:16:01,066 - INFO - Epoch 6/10 - Time: 25.95s - Val Loss: 0.5206 - Val Acc: 82.50%
# INFO:__main__:Epoch 6/10 - Time: 25.95s - Val Loss: 0.5206 - Val Acc: 82.50%
# 2026-03-21 16:16:34,013 - INFO - Epoch 7/10 - Time: 26.41s - Val Loss: 0.7089 - Val Acc: 72.32%
# INFO:__main__:Epoch 7/10 - Time: 26.41s - Val Loss: 0.7089 - Val Acc: 72.32%
# 2026-03-21 16:17:05,485 - INFO - Epoch 8/10 - Time: 24.70s - Val Loss: 0.4783 - Val Acc: 81.43%
# INFO:__main__:Epoch 8/10 - Time: 24.70s - Val Loss: 0.4783 - Val Acc: 81.43%
# 2026-03-21 16:17:36,835 - INFO - Epoch 9/10 - Time: 25.51s - Val Loss: 0.6248 - Val Acc: 75.54%
# INFO:__main__:Epoch 9/10 - Time: 25.51s - Val Loss: 0.6248 - Val Acc: 75.54%
# 2026-03-21 16:18:09,910 - INFO - Epoch 10/10 - Time: 26.50s - Val Loss: 2.4325 - Val Acc: 53.66%
# INFO:__main__:Epoch 10/10 - Time: 26.50s - Val Loss: 2.4325 - Val Acc: 53.66%
# 2026-03-21 16:18:11,482 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 16:18:11,484 - INFO -  Logged: bs=64 | epochs=10 | gpu=Tesla T4
# INFO:__main__: Logged: bs=64 | epochs=10 | gpu=Tesla T4
# 2026-03-21 16:18:11,488 - INFO - CustomCNN - Run 1/3 | Batch Size: 64 | Epochs: 20
# INFO:__main__:CustomCNN - Run 1/3 | Batch Size: 64 | Epochs: 20
# 2026-03-21 16:18:45,598 - INFO - Epoch 1/20 - Time: 25.85s - Val Loss: 1.0365 - Val Acc: 60.36%
# INFO:__main__:Epoch 1/20 - Time: 25.85s - Val Loss: 1.0365 - Val Acc: 60.36%
# 2026-03-21 16:19:17,547 - INFO - Epoch 2/20 - Time: 26.09s - Val Loss: 0.8705 - Val Acc: 62.59%
# INFO:__main__:Epoch 2/20 - Time: 26.09s - Val Loss: 0.8705 - Val Acc: 62.59%
# 2026-03-21 16:19:50,536 - INFO - Epoch 3/20 - Time: 25.90s - Val Loss: 0.7876 - Val Acc: 68.48%
# INFO:__main__:Epoch 3/20 - Time: 25.90s - Val Loss: 0.7876 - Val Acc: 68.48%
# 2026-03-21 16:20:22,063 - INFO - Epoch 4/20 - Time: 25.62s - Val Loss: 0.5728 - Val Acc: 80.27%
# INFO:__main__:Epoch 4/20 - Time: 25.62s - Val Loss: 0.5728 - Val Acc: 80.27%
# 2026-03-21 16:20:54,956 - INFO - Epoch 5/20 - Time: 25.80s - Val Loss: 1.0103 - Val Acc: 64.55%
# INFO:__main__:Epoch 5/20 - Time: 25.80s - Val Loss: 1.0103 - Val Acc: 64.55%
# 2026-03-21 16:21:26,925 - INFO - Epoch 6/20 - Time: 25.99s - Val Loss: 0.4913 - Val Acc: 82.68%
# INFO:__main__:Epoch 6/20 - Time: 25.99s - Val Loss: 0.4913 - Val Acc: 82.68%
# 2026-03-21 16:22:00,646 - INFO - Epoch 7/20 - Time: 26.43s - Val Loss: 0.5088 - Val Acc: 83.93%
# INFO:__main__:Epoch 7/20 - Time: 26.43s - Val Loss: 0.5088 - Val Acc: 83.93%
# 2026-03-21 16:22:31,340 - INFO - Epoch 8/20 - Time: 24.94s - Val Loss: 0.5677 - Val Acc: 79.20%
# INFO:__main__:Epoch 8/20 - Time: 24.94s - Val Loss: 0.5677 - Val Acc: 79.20%
# 2026-03-21 16:23:04,827 - INFO - Epoch 9/20 - Time: 26.38s - Val Loss: 0.4198 - Val Acc: 86.52%
# INFO:__main__:Epoch 9/20 - Time: 26.38s - Val Loss: 0.4198 - Val Acc: 86.52%
# 2026-03-21 16:23:37,066 - INFO - Epoch 10/20 - Time: 26.31s - Val Loss: 1.2149 - Val Acc: 64.82%
# INFO:__main__:Epoch 10/20 - Time: 26.31s - Val Loss: 1.2149 - Val Acc: 64.82%
# 2026-03-21 16:24:09,026 - INFO - Epoch 11/20 - Time: 24.83s - Val Loss: 0.5177 - Val Acc: 81.70%
# INFO:__main__:Epoch 11/20 - Time: 24.83s - Val Loss: 0.5177 - Val Acc: 81.70%
# 2026-03-21 16:24:40,725 - INFO - Epoch 12/20 - Time: 25.88s - Val Loss: 0.3781 - Val Acc: 86.43%
# INFO:__main__:Epoch 12/20 - Time: 25.88s - Val Loss: 0.3781 - Val Acc: 86.43%
# 2026-03-21 16:25:14,089 - INFO - Epoch 13/20 - Time: 26.47s - Val Loss: 0.3476 - Val Acc: 87.41%
# INFO:__main__:Epoch 13/20 - Time: 26.47s - Val Loss: 0.3476 - Val Acc: 87.41%
# 2026-03-21 16:25:46,160 - INFO - Epoch 14/20 - Time: 26.08s - Val Loss: 0.3706 - Val Acc: 87.05%
# INFO:__main__:Epoch 14/20 - Time: 26.08s - Val Loss: 0.3706 - Val Acc: 87.05%
# 2026-03-21 16:26:19,709 - INFO - Epoch 15/20 - Time: 27.26s - Val Loss: 0.3135 - Val Acc: 87.14%
# INFO:__main__:Epoch 15/20 - Time: 27.26s - Val Loss: 0.3135 - Val Acc: 87.14%
# 2026-03-21 16:26:51,313 - INFO - Epoch 16/20 - Time: 25.43s - Val Loss: 0.2765 - Val Acc: 88.75%
# INFO:__main__:Epoch 16/20 - Time: 25.43s - Val Loss: 0.2765 - Val Acc: 88.75%
# 2026-03-21 16:27:31,089 - INFO - Epoch 17/20 - Time: 31.69s - Val Loss: 0.2837 - Val Acc: 88.57%
# INFO:__main__:Epoch 17/20 - Time: 31.69s - Val Loss: 0.2837 - Val Acc: 88.57%
# 2026-03-21 16:28:05,893 - INFO - Epoch 18/20 - Time: 28.69s - Val Loss: 1.1592 - Val Acc: 72.32%
# INFO:__main__:Epoch 18/20 - Time: 28.69s - Val Loss: 1.1592 - Val Acc: 72.32%
# 2026-03-21 16:28:40,504 - INFO - Epoch 19/20 - Time: 27.35s - Val Loss: 0.2613 - Val Acc: 90.62%
# INFO:__main__:Epoch 19/20 - Time: 27.35s - Val Loss: 0.2613 - Val Acc: 90.62%
# 2026-03-21 16:29:13,349 - INFO - Epoch 20/20 - Time: 26.74s - Val Loss: 0.4091 - Val Acc: 84.55%
# INFO:__main__:Epoch 20/20 - Time: 26.74s - Val Loss: 0.4091 - Val Acc: 84.55%
# 2026-03-21 16:29:15,446 - INFO - Logged performance for CustomCNN (Run 1) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 1) to performance_logs.csv
# 2026-03-21 16:29:15,448 - INFO -  Logged: bs=64 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=64 | epochs=20 | gpu=Tesla T4
# 2026-03-21 16:29:15,450 - INFO - CustomCNN - Run 2/3 | Batch Size: 64 | Epochs: 20
# INFO:__main__:CustomCNN - Run 2/3 | Batch Size: 64 | Epochs: 20
# 2026-03-21 16:29:48,785 - INFO - Epoch 1/20 - Time: 26.41s - Val Loss: 1.1104 - Val Acc: 57.95%
# INFO:__main__:Epoch 1/20 - Time: 26.41s - Val Loss: 1.1104 - Val Acc: 57.95%
# 2026-03-21 16:30:21,467 - INFO - Epoch 2/20 - Time: 25.61s - Val Loss: 0.8490 - Val Acc: 66.70%
# INFO:__main__:Epoch 2/20 - Time: 25.61s - Val Loss: 0.8490 - Val Acc: 66.70%
# 2026-03-21 16:30:53,444 - INFO - Epoch 3/20 - Time: 26.05s - Val Loss: 0.7203 - Val Acc: 71.88%
# INFO:__main__:Epoch 3/20 - Time: 26.05s - Val Loss: 0.7203 - Val Acc: 71.88%
# 2026-03-21 16:31:27,567 - INFO - Epoch 4/20 - Time: 27.03s - Val Loss: 0.8274 - Val Acc: 66.96%
# INFO:__main__:Epoch 4/20 - Time: 27.03s - Val Loss: 0.8274 - Val Acc: 66.96%
# 2026-03-21 16:32:00,526 - INFO - Epoch 5/20 - Time: 26.82s - Val Loss: 0.9423 - Val Acc: 63.30%
# INFO:__main__:Epoch 5/20 - Time: 26.82s - Val Loss: 0.9423 - Val Acc: 63.30%
# 2026-03-21 16:32:34,626 - INFO - Epoch 6/20 - Time: 27.49s - Val Loss: 0.4843 - Val Acc: 84.20%
# INFO:__main__:Epoch 6/20 - Time: 27.49s - Val Loss: 0.4843 - Val Acc: 84.20%
# 2026-03-21 16:33:08,395 - INFO - Epoch 7/20 - Time: 26.57s - Val Loss: 0.5408 - Val Acc: 80.89%
# INFO:__main__:Epoch 7/20 - Time: 26.57s - Val Loss: 0.5408 - Val Acc: 80.89%
# 2026-03-21 16:33:40,876 - INFO - Epoch 8/20 - Time: 26.33s - Val Loss: 1.0449 - Val Acc: 63.48%
# INFO:__main__:Epoch 8/20 - Time: 26.33s - Val Loss: 1.0449 - Val Acc: 63.48%
# 2026-03-21 16:34:15,015 - INFO - Epoch 9/20 - Time: 26.76s - Val Loss: 0.6754 - Val Acc: 73.57%
# INFO:__main__:Epoch 9/20 - Time: 26.76s - Val Loss: 0.6754 - Val Acc: 73.57%
# 2026-03-21 16:34:46,552 - INFO - Epoch 10/20 - Time: 25.48s - Val Loss: 0.4163 - Val Acc: 87.23%
# INFO:__main__:Epoch 10/20 - Time: 25.48s - Val Loss: 0.4163 - Val Acc: 87.23%
# 2026-03-21 16:35:20,832 - INFO - Epoch 11/20 - Time: 26.91s - Val Loss: 0.7170 - Val Acc: 70.45%
# INFO:__main__:Epoch 11/20 - Time: 26.91s - Val Loss: 0.7170 - Val Acc: 70.45%
# 2026-03-21 16:35:54,590 - INFO - Epoch 12/20 - Time: 27.56s - Val Loss: 2.0049 - Val Acc: 61.34%
# INFO:__main__:Epoch 12/20 - Time: 27.56s - Val Loss: 2.0049 - Val Acc: 61.34%
# 2026-03-21 16:36:27,650 - INFO - Epoch 13/20 - Time: 25.84s - Val Loss: 0.6049 - Val Acc: 77.77%
# INFO:__main__:Epoch 13/20 - Time: 25.84s - Val Loss: 0.6049 - Val Acc: 77.77%
# 2026-03-21 16:37:01,310 - INFO - Epoch 14/20 - Time: 26.46s - Val Loss: 0.3110 - Val Acc: 88.66%
# INFO:__main__:Epoch 14/20 - Time: 26.46s - Val Loss: 0.3110 - Val Acc: 88.66%
# 2026-03-21 16:37:35,040 - INFO - Epoch 15/20 - Time: 27.58s - Val Loss: 0.4330 - Val Acc: 83.30%
# INFO:__main__:Epoch 15/20 - Time: 27.58s - Val Loss: 0.4330 - Val Acc: 83.30%
# 2026-03-21 16:38:09,599 - INFO - Epoch 16/20 - Time: 27.18s - Val Loss: 2.4342 - Val Acc: 62.23%
# INFO:__main__:Epoch 16/20 - Time: 27.18s - Val Loss: 2.4342 - Val Acc: 62.23%
# 2026-03-21 16:38:42,555 - INFO - Epoch 17/20 - Time: 26.92s - Val Loss: 0.3337 - Val Acc: 87.86%
# INFO:__main__:Epoch 17/20 - Time: 26.92s - Val Loss: 0.3337 - Val Acc: 87.86%
# 2026-03-21 16:39:16,895 - INFO - Epoch 18/20 - Time: 27.49s - Val Loss: 0.2816 - Val Acc: 89.38%
# INFO:__main__:Epoch 18/20 - Time: 27.49s - Val Loss: 0.2816 - Val Acc: 89.38%
# 2026-03-21 16:39:50,850 - INFO - Epoch 19/20 - Time: 26.68s - Val Loss: 0.4046 - Val Acc: 84.55%
# INFO:__main__:Epoch 19/20 - Time: 26.68s - Val Loss: 0.4046 - Val Acc: 84.55%
# 2026-03-21 16:40:23,759 - INFO - Epoch 20/20 - Time: 26.92s - Val Loss: 0.9138 - Val Acc: 72.50%
# INFO:__main__:Epoch 20/20 - Time: 26.92s - Val Loss: 0.9138 - Val Acc: 72.50%
# 2026-03-21 16:40:25,345 - INFO - Logged performance for CustomCNN (Run 2) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 2) to performance_logs.csv
# 2026-03-21 16:40:25,347 - INFO -  Logged: bs=64 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=64 | epochs=20 | gpu=Tesla T4
# 2026-03-21 16:40:25,349 - INFO - CustomCNN - Run 3/3 | Batch Size: 64 | Epochs: 20
# INFO:__main__:CustomCNN - Run 3/3 | Batch Size: 64 | Epochs: 20
# 2026-03-21 16:41:00,584 - INFO - Epoch 1/20 - Time: 27.71s - Val Loss: 0.9840 - Val Acc: 62.68%
# INFO:__main__:Epoch 1/20 - Time: 27.71s - Val Loss: 0.9840 - Val Acc: 62.68%
# 2026-03-21 16:41:33,837 - INFO - Epoch 2/20 - Time: 26.28s - Val Loss: 0.8332 - Val Acc: 61.88%
# INFO:__main__:Epoch 2/20 - Time: 26.28s - Val Loss: 0.8332 - Val Acc: 61.88%
# 2026-03-21 16:42:07,356 - INFO - Epoch 3/20 - Time: 27.48s - Val Loss: 0.7130 - Val Acc: 74.55%
# INFO:__main__:Epoch 3/20 - Time: 27.48s - Val Loss: 0.7130 - Val Acc: 74.55%
# 2026-03-21 16:42:41,908 - INFO - Epoch 4/20 - Time: 27.21s - Val Loss: 0.9157 - Val Acc: 62.95%
# INFO:__main__:Epoch 4/20 - Time: 27.21s - Val Loss: 0.9157 - Val Acc: 62.95%
# 2026-03-21 16:43:13,694 - INFO - Epoch 5/20 - Time: 25.76s - Val Loss: 0.5100 - Val Acc: 82.77%
# INFO:__main__:Epoch 5/20 - Time: 25.76s - Val Loss: 0.5100 - Val Acc: 82.77%
# 2026-03-21 16:43:47,158 - INFO - Epoch 6/20 - Time: 26.19s - Val Loss: 0.5433 - Val Acc: 81.88%
# INFO:__main__:Epoch 6/20 - Time: 26.19s - Val Loss: 0.5433 - Val Acc: 81.88%
# 2026-03-21 16:44:21,500 - INFO - Epoch 7/20 - Time: 27.48s - Val Loss: 0.8994 - Val Acc: 65.18%
# INFO:__main__:Epoch 7/20 - Time: 27.48s - Val Loss: 0.8994 - Val Acc: 65.18%
# 2026-03-21 16:44:55,355 - INFO - Epoch 8/20 - Time: 27.72s - Val Loss: 0.8576 - Val Acc: 70.62%
# INFO:__main__:Epoch 8/20 - Time: 27.72s - Val Loss: 0.8576 - Val Acc: 70.62%
# 2026-03-21 16:45:29,792 - INFO - Epoch 9/20 - Time: 27.25s - Val Loss: 0.4926 - Val Acc: 83.57%
# INFO:__main__:Epoch 9/20 - Time: 27.25s - Val Loss: 0.4926 - Val Acc: 83.57%
# 2026-03-21 16:46:03,272 - INFO - Epoch 10/20 - Time: 27.45s - Val Loss: 1.2532 - Val Acc: 65.09%
# INFO:__main__:Epoch 10/20 - Time: 27.45s - Val Loss: 1.2532 - Val Acc: 65.09%
# 2026-03-21 16:46:37,890 - INFO - Epoch 11/20 - Time: 28.44s - Val Loss: 0.3909 - Val Acc: 85.18%
# INFO:__main__:Epoch 11/20 - Time: 28.44s - Val Loss: 0.3909 - Val Acc: 85.18%
# 2026-03-21 16:47:10,244 - INFO - Epoch 12/20 - Time: 25.54s - Val Loss: 0.5448 - Val Acc: 82.77%
# INFO:__main__:Epoch 12/20 - Time: 25.54s - Val Loss: 0.5448 - Val Acc: 82.77%
# 2026-03-21 16:47:42,952 - INFO - Epoch 13/20 - Time: 26.69s - Val Loss: 0.3349 - Val Acc: 87.77%
# INFO:__main__:Epoch 13/20 - Time: 26.69s - Val Loss: 0.3349 - Val Acc: 87.77%
# 2026-03-21 16:48:17,774 - INFO - Epoch 14/20 - Time: 27.60s - Val Loss: 0.3361 - Val Acc: 88.57%
# INFO:__main__:Epoch 14/20 - Time: 27.60s - Val Loss: 0.3361 - Val Acc: 88.57%
# 2026-03-21 16:48:49,664 - INFO - Epoch 15/20 - Time: 25.85s - Val Loss: 0.4714 - Val Acc: 83.04%
# INFO:__main__:Epoch 15/20 - Time: 25.85s - Val Loss: 0.4714 - Val Acc: 83.04%
# 2026-03-21 16:49:23,828 - INFO - Epoch 16/20 - Time: 26.97s - Val Loss: 0.3187 - Val Acc: 88.04%
# INFO:__main__:Epoch 16/20 - Time: 26.97s - Val Loss: 0.3187 - Val Acc: 88.04%
# 2026-03-21 16:49:55,760 - INFO - Epoch 17/20 - Time: 26.00s - Val Loss: 0.4768 - Val Acc: 83.04%
# INFO:__main__:Epoch 17/20 - Time: 26.00s - Val Loss: 0.4768 - Val Acc: 83.04%
# 2026-03-21 16:50:30,751 - INFO - Epoch 18/20 - Time: 27.58s - Val Loss: 0.3405 - Val Acc: 87.05%
# INFO:__main__:Epoch 18/20 - Time: 27.58s - Val Loss: 0.3405 - Val Acc: 87.05%
# 2026-03-21 16:51:05,062 - INFO - Epoch 19/20 - Time: 26.62s - Val Loss: 0.2863 - Val Acc: 89.46%
# INFO:__main__:Epoch 19/20 - Time: 26.62s - Val Loss: 0.2863 - Val Acc: 89.46%
# 2026-03-21 16:51:37,548 - INFO - Epoch 20/20 - Time: 26.34s - Val Loss: 0.2793 - Val Acc: 89.38%
# INFO:__main__:Epoch 20/20 - Time: 26.34s - Val Loss: 0.2793 - Val Acc: 89.38%
# 2026-03-21 16:51:38,877 - INFO - Logged performance for CustomCNN (Run 3) to performance_logs.csv
# INFO:__main__:Logged performance for CustomCNN (Run 3) to performance_logs.csv
# 2026-03-21 16:51:38,879 - INFO -  Logged: bs=64 | epochs=20 | gpu=Tesla T4
# INFO:__main__: Logged: bs=64 | epochs=20 | gpu=Tesla T4
# 2026-03-21 16:51:38,880 - INFO - Completed all runs for CustomCNN. Performance metrics logged to performance_logs.csv.
# INFO:__main__:Completed all runs for CustomCNN. Performance metrics logged to performance_logs.csv.
# 2026-03-21 16:51:38,881 - INFO - Best validation accuracy across all runs: 91.96%
# INFO:__main__:Best validation accuracy across all runs: 91.96%

# %% [markdown]
# ### 6 · Final Evaluation on Test Set

# %%
## After all runs are complete, we can analyze the logged performance metrics in performance_logs.csv to compare the impact of batch size and epoch count on training time, inference latency, GPU memory usage, and model performance (accuracy and F1 score).

device = torch.device('cuda') if torch.cuda.is_available() else torch.device("cpu")
_, _, test_loader = make_loaders(batch_size=32) # Use a standard batch size for testing

model = EfficientNetB0Classifier(num_classes=len(CLASSES)).to(device)
model.load_state_dict(torch.load("best_efficientnet_b0.pth", map_location=device)) # Load the best model checkpoint saved during training

model.eval()

y_true, y_pred = [], []
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

logger.info(classification_report(y_true, y_pred, target_names=CLASSES))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(7, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES)
plt.title('EfficientNet-B0 - Confusion Matrix on Test Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()
